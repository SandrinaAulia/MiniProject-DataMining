# %% [markdown]
# <a href="https://colab.research.google.com/github/SandrinaAulia/MiniProject-DataMining/blob/main/DEPLOYMENT_DATA_MINING_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Analisis & Strategi Membangun Pengalaman Pengguna Sebagai Faktor Kunci Untuk Meningkatkan Unduhan Aplikasi pada Mobile App Store**

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

from sklearn.metrics import accuracy_score
from sklearn.tree import export_graphviz
import graphviz

# %% [markdown]
# #**BUSINESS UNDERSTANDING**

# %% [markdown]
# ##**Business Objective**

# %% [markdown]
# Tujuan utama dari analisis ini adalah memberikan pedoman bagi pengembang aplikasi untuk memperhatikan strategi dan analisis yang relevan guna meningkatkan pertumbuhan dan retensi pengguna di masa depan, serta memastikan aplikasi mereka dapat ditemukan dengan mudah oleh lebih banyak orang. Selain itu, dengan menerapkan analisis yang tepat terhadap data Mobile App Store atau toko aplikasi seluler tersebut diharapkan hasil analisis ini dapat memberikan wawasan bagi pengembang aplikasi dan pemangku kepentingan lainnya dalam upaya meningkatkan kualitas aplikasi, mengidentifikasi tren, memperluas pangsa pasar dan merencanakan langkah-langkah yang diperlukan untuk mengoptimalkan pertumbuhan dan keberhasilan aplikasi mereka di toko aplikasi seluler (Mobile App Store).

# %% [markdown]
# ##**Assess Situation**

# %% [markdown]
# Dengan lingkungan yang terus berkembang dan pertumbuhan pesat jumlah aplikasi saat ini menambah tingkat persaingan yang tinggi di pasar. Para pengembang perlu memperhatikan berbagai faktor kunci untuk mengamankan kesuksesan aplikasi mereka di masa depan. Pemahaman yang mendalam tentang tren pasar, termasuk preferensi pengguna, aplikasi yang paling diminati, perkiraan harga yang sesuai, ukuran serta genre yang paling diinginkan oleh pengguna dan lain sebagainya juga harus diperhatikan. Selanjutnya, pengetahuan tentang pesaing di pasar sangat penting. Para pengembang perlu menganalisis aplikasi serupa yang sudah ada di pasar, mengevaluasi rating serta ulasan pengguna dan faktor eksternal lainnya yang mempengaruhi perkembangan teknologi.

# %% [markdown]
# ##**Data Mining Goals**

# %% [markdown]
# Tujuan dari analisis data ini adalah untuk mengidentifikasi faktor-faktor yang mempengaruhi perilaku unduhan dan penggunaan aplikasi seluler dalam toko aplikasi seluler (Mobile App Store), serta mengetahui faktor-faktor mana yang paling berpengaruh terhadap keberhasilan aplikasi tersebut menggunakan pemodelan prediktif. Analisis data mining juga bertujuan untuk mengidentifikasi pola dalam perilaku pengguna, seperti size atau ukuran, price atau harga, dan preferensi genre aplikasi. Selain itu, tujuan utamanya adalah memprediksi potensi kesuksesan suatu aplikasi dalam mencapai unduhan yang tinggi dan retensi pengguna yang baik di masa depan. Dengan memahami pola dan faktor-faktor yang mempengaruhi perilaku pengguna, pengembang aplikasi dapat menganalisis dan menyusun strategi pemasaran yang lebih efektif serta mengambil keputusan yang lebih baik dalam mengembangkan dan memasarkan aplikasi mereka di toko aplikasi seluler iOS (Mobile App Store).

# %% [markdown]
# ##**Project Plan**

# %% [markdown]
# Rencana proyek ini akan dimulai dengan pengumpulan data yang relevan terkait aplikasi seluler dari berbagai sumber yang tersedia, termasuk data dari Mobile App Store atau toko aplikasi seluler yang sudah ada sebelumnya. Setelah itu, dataset akan disaring dan dilakukan preprocessing data untuk memastikan kualitas dan konsistensi dataset yang akan digunakan dalam analisis. Langkah selanjutnya adalah melakukan eksplorasi data untuk memahami pola-pola yang ada dalam perilaku unduhan dan penggunaan aplikasi seluler (Mobile App), serta mengidentifikasi hubungan antar variabel yang relevan. Kemudian, dilakukan analisis data mining menggunakan pemodelan prediktif untuk mengidentifikasi faktor-faktor yang mempengaruhi keberhasilan aplikasi seluler, seperti ukuran aplikasi, harga, genre, ulasan dan lain sebagainya. Hasil dari analisis ini akan digunakan untuk menyusun strategi yang tepat guna meningkatkan pertumbuhan dan retensi pengguna di masa depan, serta memastikan aplikasi dapat ditemukan dengan mudah oleh lebih banyak orang. Dengan demikian, rencana proyek ini bertujuan untuk memberikan wawasan yang berharga bagi pengembang aplikasi dan pemangku kepentingan lainnya dalam upaya mengoptimalkan keberhasilan aplikasi mereka di toko aplikasi seluler (Mobile App Store).

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# ##**Collect Initial Data**

# %% [markdown]
# Sumber Data : [Dataset Mobile App (Apple iOS App Store)](https://www.kaggle.com/datasets/ramamet4/app-store-apple-data-set-10k-apps/data)
#
# Data diekstraksi dari iTunes Search API di situs web Apple Inc. yang berisi tentang komponen aplikasi, rating dari pengguna serta komponen lainnya yang berkaitan untuk memahami strategi yang akan mendorong pertumbuhan dan retensi pengguna di masa depan.

# %%
# Menampilkan dataraw/dataset
df = pd.read_csv("https://raw.githubusercontent.com/SandrinaAulia/MiniProject-DataMining/main/AppleStore.csv")
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
# Menampilkan 5 baris pertama
df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
# Menampilkan 5 baris terakhir
df.tail()
# Out:
#       Unnamed: 0          id                                 track_name  \
# 7192       11081  1187617475                                      Kubik
# 7193       11082  1187682390                          VR Roller-Coaster
# 7194       11087  1187779532      Bret Michaels Emojis + Lyric Keyboard
# 7195       11089  1187838770  VR Roller Coaster World - Virtual Reality
# 7196       11097  1188375727               Escape the Sweet Shop Series
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 7192   126644224      USD   0.00               142                75
# 7193   120760320      USD   0.00                30                30
# 7194   111322112      USD   1.99                15                 0
# 7195    97235968      USD   0.00                85                32
# 7196    90898432      USD   0.00                 3                 3
#
#       user_rating  user_rating_ver     ver cont_rating prime_genre  \
# ...

# %% [markdown]
# ##**Describe Data**

# %% [markdown]
# ####Informasi Dasar

# %%
# Menampilkan Jumlah Baris dan Kolom
df.shape
# Out:
# (7197, 17)

# %%
# Menampilkan Nama Kolom
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %% [markdown]
# Pada data diatas yang telah ditampilkan memiliki jumlah baris dan kolom yakni sebanyak **7197 baris** dan **17 kolom**, dimana untuk kolom-kolom tersebut terdiri dari kolom Unnamed atau kolom tidak bernama, id, track name (nama aplikasi), size_bytes (ukuran aplikasi) dalam bytes dan lain sebagainya seperti yang sudah tertampilkan pada informasi dasar diatas.

# %% [markdown]
# ####Informasi Lanjutan

# %%
# Untuk menampilkan informasi dari dataraw/dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7197 non-null   int64
#  1   id                7197 non-null   int64
#  2   track_name        7197 non-null   object
#  3   size_bytes        7197 non-null   int64
#  4   currency          7197 non-null   object
#  5   price             7197 non-null   float64
#  6   rating_count_tot  7197 non-null   int64
#  7   rating_count_ver  7197 non-null   int64
#  8   user_rating       7197 non-null   float64
#  9   user_rating_ver   7197 non-null   float64
#  10  ver               7197 non-null   object
#  11  cont_rating       7197 non-null   object
#  12  prime_genre       7197 non-null   object
#  13  sup_devices.num   7197 non-null   int64
#  14  ipadSc_urls.num   7197 non-null   int64
#  15  lang.num          7197 non-null   int64
# ...

# %% [markdown]
# Pernyataan **"Non-Null Count : 7197"** menunjukkan bahwa dari total entri/data dalam kolom tersebut, ada 7197 data yang memiliki nilai non-null, atau dengan kata lain, tidak ada nilai null (atau missing value) dalam kolom tersebut.
#
# **Tipe Data :**
#
# * Integer64 (int64): Ini adalah tipe data untuk bilangan bulat.
#
# * Object: Tipe data object dalam Pandas biasanya digunakan untuk menyimpan teks atau kombinasi teks dan angka.
#
# * Float64 (float64): Tipe data float64 adalah representasi numerik untuk angka desimal.
#
#
# **Keterangan :**
#
# 1. **Unnamed** :yakni kolom tidak bernama memiliki tipe data int64 (integer)
# 2. **id** : yakni Id dari App dan memiliki tipe data int64 (integer)
# 3. **track_name** : yakni Nama App memiliki tipe data object
# 4. **size_bytes** : yakni Ukuran dari App dalam Bytes memiliki tipe data int64 (integer)
# 5. **currency** : yakni Jenis Mata Uang yang digunakan memiliki tipe data object
# 6. **price** : yakni Harga App memiliki tipe data float64
# 7. **rating_count_tot** : yakni Peringkat Pengguna dihitung (untuk semua versi)memiliki tipe data int64 (integer)
# 8. **rating_count_ver** : yakni Jumlah rating/Peringkat Pengguna (untuk versi saat ini) memiliki tipe data int64 (integer)
# 9. **user_rating** : yakni Nilai Rata-rata Peringkat Pengguna (untuk semua versi) memiliki tipe data float64
# 11. **user_rating_ver** : yakni Nilai Rata-rata Peringkat Pengguna (untuk versi saat ini) memiliki tipe data float64
# 12. **ver** : yakni Kode versi yang terbaru memiliki tipe data object
# 13. **cont_rating** : yakni Rating/Peringkat dari Konten memiliki tipe data object
# 14. **prime_genre** : yakni Genre Utama memiliki tipe data object
# 15. **sup_devices.num** : yakni Jumlah perangkat pendukung memiliki tipe data int64 (integer)
# 16. **ipadSc_urls.num** : yakni Jumlah screenshot yang ditampilkan untuk ditampilkan memiliki tipe data int64 (integer)
# 17. **lang.num** : yakni Jumlah bahasa yang didukung memiliki tipe data int64 (integer)
# 18. **vpp_lic** : yakni Perizinan Berbasis Perangkat Vpp Diaktifkan memiliki tipe data int64 (integer)

# %% [markdown]
# ####Informasi Statistik Deskriptif

# %%
# Menampilkan hasil statistik deskriptif untuk kolom numerik dalam data frame
df.describe()
# Out:
#          Unnamed: 0            id    size_bytes        price  \
# count   7197.000000  7.197000e+03  7.197000e+03  7197.000000
# mean    4759.069612  8.631310e+08  1.991345e+08     1.726218
# std     3093.625213  2.712368e+08  3.592069e+08     5.833006
# min        1.000000  2.816565e+08  5.898240e+05     0.000000
# 25%     2090.000000  6.000937e+08  4.692275e+07     0.000000
# 50%     4380.000000  9.781482e+08  9.715302e+07     0.000000
# 75%     7223.000000  1.082310e+09  1.819249e+08     1.990000
# max    11097.000000  1.188376e+09  4.025970e+09   299.990000
#
#        rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# count      7.197000e+03       7197.000000  7197.000000      7197.000000
# mean       1.289291e+04        460.373906     3.526956         3.253578
# std        7.573941e+04       3920.455183     1.517948         1.809363
# min        0.000000e+00          0.000000     0.000000         0.000000
# ...

# %% [markdown]
# Ini memberikan ringkasan statistik deskriptif untuk kolom numerik dalam DataFrame. Mencakup count(total data), mean, std (standar deviasi), min, quartil (25%, 50%, 75%), dan max untuk masing-masing kolom.
#
# Seperti contoh :
# **Kolom size_bytes** :
# 1. Rata-rata ukuran aplikasi dalam data adalah 1.99 bytes
# 2. Standar deviasi yakni 3.59 bytes
# 3. Rentang ukuran aplikasi sekitar 5.89 hingga 4.02 bytes
# 4. Q1 (kuartil ke-1 atau 25%) dari ukuran aplikasi yakni 4.69
# 5. Q2/median (kuartil ke-2 atau 50%) yakni skitar 9.71 bytes
# 6. Q3 (kuartil ke-3 atau 75%) adalah 1.81 bytes.
#
# Dari hal ini bisa dilihat bahwa mayoritas pengguna aplikasi menggunakan aplikasi berukuran 4.69 hingga 9.71 bytes.

# %%
# Menampilkan hasil statistik deskriptif baik itu numerik maupun non-numerik dalam data frame.
df.describe(include="all")
# Out:
#           Unnamed: 0            id         track_name    size_bytes currency  \
# count    7197.000000  7.197000e+03               7197  7.197000e+03     7197
# unique           NaN           NaN               7195           NaN        1
# top              NaN           NaN  VR Roller Coaster           NaN      USD
# freq             NaN           NaN                  2           NaN     7197
# mean     4759.069612  8.631310e+08                NaN  1.991345e+08      NaN
# std      3093.625213  2.712368e+08                NaN  3.592069e+08      NaN
# min         1.000000  2.816565e+08                NaN  5.898240e+05      NaN
# 25%      2090.000000  6.000937e+08                NaN  4.692275e+07      NaN
# 50%      4380.000000  9.781482e+08                NaN  9.715302e+07      NaN
# 75%      7223.000000  1.082310e+09                NaN  1.819249e+08      NaN
# max     11097.000000  1.188376e+09                NaN  4.025970e+09      NaN
#
# ...

# %% [markdown]
# Ini memberikan ringkasan statistik deskriptif untuk semua kolom dalam DataFrame, baik itu numerik maupun non-numerik. Untuk kolom numerik, informasinya sama seperti df.describe(). Namun, untuk kolom **non-numerik** (seperti objek), itu akan menyertakan jumlah unik, nilai yang paling sering muncul (top), dan frekuensi nilai teratas (freq).

# %%
# Menampilkan Korelasi
df.corr(numeric_only=True)
# Out:
#                   Unnamed: 0        id  size_bytes     price  \
# Unnamed: 0          1.000000  0.910714    0.041277 -0.074326
# id                  0.910714  1.000000    0.077486 -0.075247
# size_bytes          0.041277  0.077486    1.000000  0.182392
# price              -0.074326 -0.075247    0.182392  1.000000
# rating_count_tot   -0.168640 -0.201976    0.004486 -0.039044
# rating_count_ver   -0.064717 -0.072784    0.006337 -0.018012
# user_rating        -0.204867 -0.185178    0.066256  0.046601
# user_rating_ver    -0.127580 -0.109849    0.086075  0.025173
# sup_devices.num     0.024648  0.033605   -0.118347 -0.115361
# ipadSc_urls.num     0.014589  0.052082    0.152697  0.066100
# lang.num           -0.148487 -0.128932    0.004614 -0.006713
# vpp_lic             0.000501  0.017743   -0.150418 -0.029942
#
#                   rating_count_tot  rating_count_ver  user_rating  \
# Unnamed: 0               -0.168640         -0.064717    -0.204867
# ...

# %% [markdown]
# Korelasi :
#
# **1. Sizebytes**
# * Size_bytes dan user_rating_ver: Korelasi ini menunjukkan hubungan positif
# lemah (0,086075) antara ukuran file aplikasi (size_bytes) dan peringkat pengguna untuk versi aplikasi yang saat ini diulas. Ini menunjukkan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki peringkat pengguna versi terbaru yang sedikit lebih tinggi.
#
# * Size_bytes dan price: Korelasi ini menunjukkan hubungan positif lemah (0,182392) antara ukuran file aplikasi (size_bytes) dan harga aplikasi. Ini menunjukkan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki harga yang sedikit lebih tinggi.
#
# * Size_bytes dan user_rating: Korelasi ini menunjukkan hubungan positif lemah (0,066256) antara ukuran file aplikasi (size_bytes) dan peringkat pengguna keseluruhan. Ini menunjukkan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki peringkat pengguna yang sedikit lebih tinggi.
#
# * Size_bytes dan rating_count_ver: Korelasi ini menunjukkan bahwa tidak ada hubungan linier yang signifikan (0,006337) antara ukuran file aplikasi (size_bytes) dan jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas.
#
# * Size_bytes dan rating_count_tot: Korelasi ini menunjukkan bahwa tidak ada hubungan linier yang signifikan (0,004486) antara ukuran file aplikasi (size_bytes) dan jumlah total peringkat pengguna.
#
# * Size_bytes dan sup_devices.num: Korelasi ini menunjukkan hubungan negatif lemah (-0,118347) antara ukuran file aplikasi (size_bytes) dan jumlah perangkat yang mendukung aplikasi tersebut. Ini mungkin menunjukkan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki kompatibilitas yang sedikit lebih rendah dengan jumlah perangkat.
#
# * Size_bytes dan ipadSc_urls.num: Korelasi ini menunjukkan hubungan positif lemah (0,152697) antara ukuran file aplikasi (size_bytes) dan jumlah screenshot untuk perangkat iPad. Ini menandakan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki lebih banyak screenshot yang tersedia untuk perangkat iPad.
#
# * Size_bytes dan lang.num: Korelasi ini menunjukkan bahwa tidak ada hubungan linier yang signifikan (0,004614) antara ukuran file aplikasi (size_bytes) dan jumlah bahasa yang didukung oleh aplikasi.
#
# * Size_bytes dan vpp_lic: Korelasi ini menunjukkan hubungan negatif lemah (-0,150418) antara ukuran file aplikasi (size_bytes) dan status lisensi VPP (Volume Purchase Program). Ini mungkin menunjukkan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki peluang yang sedikit lebih rendah untuk memiliki lisensi VPP.
#
# **2. Price**
#
# * rating_count_tot dan price: Terdapat hubungan negatif lemah (-0.039044) antara jumlah total peringkat pengguna dan harga aplikasi. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna yang lebih tinggi cenderung memiliki harga yang sedikit lebih rendah, meskipun korelasinya sangat lemah.
#
# * rating_count_ver dan price: Terdapat hubungan negatif lemah (-0.018012) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan harga aplikasi. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna versi yang lebih tinggi cenderung memiliki harga yang sedikit lebih rendah, meskipun korelasinya sangat lemah.
#
# * user_rating dan price: Terdapat hubungan positif lemah (0.046601) antara peringkat pengguna keseluruhan dan harga aplikasi. Ini menunjukkan bahwa aplikasi dengan peringkat pengguna yang lebih tinggi cenderung memiliki harga yang sedikit lebih tinggi.
#
# * user_rating_ver dan price: Terdapat hubungan positif lemah (0.025173) antara peringkat pengguna untuk versi aplikasi yang saat ini diulas dan harga aplikasi. Ini menunjukkan bahwa aplikasi dengan peringkat pengguna versi yang lebih tinggi cenderung memiliki harga yang sedikit lebih tinggi.
#
# * sup_devices.num dan price: Terdapat hubungan negatif lemah (-0.115361) antara jumlah perangkat yang mendukung aplikasi dan harga aplikasi. Ini mungkin menunjukkan bahwa aplikasi dengan dukungan perangkat yang lebih luas cenderung memiliki harga yang sedikit lebih rendah.
#
# * ipadSc_urls.num dan price: Terdapat hubungan positif lemah (0.066100) antara jumlah screenshot untuk perangkat iPad dan harga aplikasi. Ini menandakan bahwa aplikasi dengan lebih banyak screenshot untuk perangkat iPad cenderung memiliki harga yang sedikit lebih tinggi.
#
# * lang.num dan price: Tidak terdapat hubungan linier yang signifikan (0.006713) antara jumlah bahasa yang didukung oleh aplikasi dan harga aplikasi.
#
# * vpp_lic dan price: Terdapat hubungan negatif lemah (-0.029942) antara status lisensi VPP (Volume Purchase Program) dan harga aplikasi. Ini mungkin menunjukkan bahwa aplikasi dengan lisensi VPP cenderung memiliki harga yang sedikit lebih rendah.
#
#
# **3. rating_count_ver**
# * rating_count_ver dan user_rating: Terdapat hubungan positif lemah (0.068754) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan peringkat pengguna keseluruhan. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna versi yang lebih tinggi cenderung memiliki peringkat pengguna keseluruhan yang juga lebih tinggi.
#
# * rating_count_ver dan user_rating_ver: Terdapat hubungan positif lemah (0.077840) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan peringkat pengguna untuk versi aplikasi tersebut. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna versi yang lebih tinggi cenderung memiliki peringkat pengguna versi tersebut yang juga lebih tinggi.
#
# * rating_count_ver dan sup_devices.num: Terdapat hubungan positif lemah (0.037951) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah perangkat yang mendukung aplikasi. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna versi yang lebih tinggi cenderung memiliki dukungan perangkat yang lebih luas.
#
# * rating_count_ver dan ipadSc_urls.num: Terdapat hubungan positif lemah (0.024333) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah screenshot untuk perangkat iPad. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna versi yang lebih tinggi cenderung memiliki lebih banyak screenshot untuk perangkat iPad.
#
# * rating_count_ver dan lang.num: Tidak terdapat hubungan linier yang signifikan (0.013287) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah bahasa yang didukung oleh aplikasi.
#
# * rating_count_ver dan vpp_lic: Tidak terdapat hubungan linier yang signifikan (0.006460) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan status lisensi VPP (Volume Purchase Program).
#
#
# **4. user_rating**
# * user_rating dan user_rating_ver: Terdapat hubungan positif yang sangat kuat (0.774140) antara peringkat pengguna keseluruhan dan peringkat pengguna untuk versi aplikasi yang saat ini diulas. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi secara keseluruhan juga cenderung mendapatkan peringkat tinggi untuk versi aplikasi yang saat ini diulas.
#
# * user_rating dan sup_devices.num: Terdapat hubungan negatif lemah (-0.042451) antara peringkat pengguna keseluruhan dan jumlah perangkat yang mendukung aplikasi. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi cenderung memiliki dukungan perangkat yang lebih rendah.
#
# * user_rating dan ipadSc_urls.num: Terdapat hubungan positif yang kuat (0.265671) antara peringkat pengguna keseluruhan dan jumlah screenshot untuk perangkat iPad. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi cenderung memiliki lebih banyak screenshot untuk perangkat iPad.
#
# * user_rating dan lang.num: Terdapat hubungan positif (0.170976) antara peringkat pengguna keseluruhan dan jumlah bahasa yang didukung oleh aplikasi. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi cenderung mendukung lebih banyak bahasa.
#
# * user_rating dan vpp_lic: Terdapat hubungan positif lemah (0.069816) antara peringkat pengguna keseluruhan dan status lisensi VPP (Volume Purchase Program). Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi cenderung memiliki kemungkinan sedikit lebih tinggi untuk memiliki lisensi VPP.
#
#
# **5. user_rating_ver**
#
# * user_rating_ver dan sup_devices.num: Terdapat hubungan negatif lemah (-0.018901) antara peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah perangkat yang mendukung aplikasi. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi untuk versi aplikasi yang saat ini diulas cenderung memiliki dukungan perangkat yang sedikit lebih rendah.
#
# * user_rating_ver dan ipadSc_urls.num: Terdapat hubungan positif yang kuat (0.275737) antara peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah screenshot untuk perangkat iPad. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi untuk versi aplikasi yang saat ini diulas cenderung memiliki lebih banyak screenshot untuk perangkat iPad.
#
# * user_rating_ver dan lang.num: Terdapat hubungan positif (0.175580) antara peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah bahasa yang didukung oleh aplikasi. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi untuk versi aplikasi yang saat ini diulas cenderung mendukung lebih banyak bahasa.
#
# * user_rating_ver dan vpp_lic: Terdapat hubungan positif lemah (0.050094) antara peringkat pengguna untuk versi aplikasi yang saat ini diulas dan status lisensi VPP (Volume Purchase Program). Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi untuk versi aplikasi yang saat ini diulas cenderung memiliki kemungkinan sedikit lebih tinggi untuk memiliki lisensi VPP.
#
# **6. sup_devices.num**
# * sup_devices.num dan ipadSc_urls.num: Terdapat hubungan negatif lemah (-0.037728) antara jumlah perangkat yang mendukung aplikasi dan jumlah screenshot untuk perangkat iPad. Ini menunjukkan bahwa aplikasi dengan dukungan perangkat yang lebih luas cenderung memiliki sedikit lebih sedikit screenshot untuk perangkat iPad.
#
# * sup_devices.num dan lang.num: Terdapat hubungan negatif lemah (-0.041681) antara jumlah perangkat yang mendukung aplikasi dan jumlah bahasa yang didukung oleh aplikasi. Ini menunjukkan bahwa aplikasi dengan dukungan perangkat yang lebih luas cenderung mendukung sedikit lebih sedikit bahasa.
#
# * sup_devices.num dan vpp_lic: Terdapat hubungan negatif lemah (-0.037109) antara jumlah perangkat yang mendukung aplikasi dan status lisensi VPP (Volume Purchase Program). Ini menunjukkan bahwa aplikasi dengan dukungan perangkat yang lebih luas cenderung memiliki peluang sedikit lebih rendah untuk memiliki lisensi VPP.
#
#
# **7. ipadSc_urls.num**
# * ipadSc_urls.num dan lang.num: Terdapat hubungan positif (0.088378) antara jumlah screenshot untuk perangkat iPad dan jumlah bahasa yang didukung oleh aplikasi. Ini menunjukkan bahwa aplikasi dengan lebih banyak screenshot untuk perangkat iPad cenderung juga mendukung lebih banyak bahasa.
#
# * ipadSc_urls.num dan vpp_lic: Terdapat hubungan positif (0.071901) antara jumlah screenshot untuk perangkat iPad dan status lisensi VPP (Volume Purchase Program). Ini menunjukkan bahwa aplikasi dengan lebih banyak screenshot untuk perangkat iPad cenderung memiliki peluang sedikit lebih tinggi untuk memiliki lisensi VPP.
#
# **8. lang.num**
#
# lang.num dan vpp_lic: Terdapat hubungan positif lemah (0.032477) antara jumlah bahasa yang didukung oleh aplikasi dan status lisensi VPP (Volume Purchase Program). Ini menunjukkan bahwa aplikasi yang mendukung lebih banyak bahasa cenderung memiliki peluang sedikit lebih tinggi untuk memiliki lisensi VPP.

# %% [markdown]
# ##**Exploratory Data Analysis**

# %%
# Konversi ukuran dari bytes ke Mega Bytes
df['size_mb'] = df['size_bytes'] / 1000000
summary_stats = df['size_mb'].describe() # Menampilkan statistik
print(summary_stats)
# Out:
# count    7197.000000
# mean      199.134454
# std       359.206914
# min         0.589824
# 25%        46.922752
# 50%        97.153024
# 75%       181.924864
# max      4025.969664
# Name: size_mb, dtype: float64

# %%
# Pembuatan kolom baru 'SizeCatg atau Size Category' dan inisialisasi dengan ukuran aplikasi dalam string
df['SizeCatg'] = df['size_mb'].astype(str)

# Proses pengklasifikasian aplikasi berdasarkan ukuran
for i in range(len(df['SizeCatg'])):
    if df.loc[i, 'size_mb'] < 100:
        df.loc[i, 'SizeCatg'] = 'Small Size App'
    elif df.loc[i, 'size_mb'] >= 100 and df.loc[i, 'size_mb'] < 300:
        df.loc[i, 'SizeCatg'] = 'Medium Size App'
    elif df.loc[i, 'size_mb'] >= 300 and df.loc[i, 'size_mb'] <= 5000:
        df.loc[i, 'SizeCatg'] = 'Big Size App'

# Mengubah klasifikasi ke format category
df['SizeCatg'] = pd.Categorical(df['SizeCatg'], categories=['Small Size App', 'Medium Size App', 'Big Size App'], ordered=True)

# Total masing-masing kategori ukuran aplikasi
summary_stats = df['SizeCatg'].value_counts()

print(summary_stats)
# Out:
# SizeCatg
# Small Size App     3702
# Medium Size App    2506
# Big Size App        989
# Name: count, dtype: int64

# %%
# Jumlah Aplikasi berdasarkan Kategori Ukuran Aplikasi (size_bytes) dalam Plot Bar menggunakan Seaborn
sns.barplot(x=summary_stats.index, y=summary_stats.values, hue=summary_stats.index, palette="BuGn", legend=False)
plt.title('Jumlah Aplikasi iOS App Store Berdasarkan Kategori Ukuran')
plt.xlabel('Kategori Ukuran Aplikasi')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# Berdasarkan bar plot/grafik di atas, terlihat bahwa jumlah aplikasi dalam kategori ukuran kecil (Small Size App) > 3500, sedangkan jumlah aplikasi dalam kategori ukuran menengah (Medium Size App) sebanyak kurang lebih 2500, dan jumlah aplikasi dalam kategori ukuran besar (Big Size App) mendekati angka 1000. Meskipun perbedaan jumlahnya tidak signifikan, namun grafik menunjukkan bahwa aplikasi dalam kategori ukuran kecil memiliki jumlah yang paling banyak dibandingkan dengan kategori ukuran lainnya. Ini menunjukkan bahwa mayoritas aplikasi dalam dataset memiliki ukuran yang relatif kecil.

# %%
# Kategori Ukuran Aplikasi (size_bytes) berdasarkan Persentase menggunakan Pie Plot
sizes = df['SizeCatg'].value_counts()
colors = ['Honeydew', 'darkseagreen', 'seagreen']

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=sizes.index, autopct='%1.1f%%',startangle=160, colors=colors)
plt.title('Persentase Kategori Ukuran Aplikasi')
plt.axis('equal')  # Memastikan plot berbentuk lingkaran
plt.show()

# %% [markdown]
# Berdasarkan pie plot di atas, dapat disimpulkan bahwa jumlah aplikasi dalam kategori ukuran kecil (Small Size App) mendominasi dengan proporsi sebesar 51,4% dari total aplikasi. Diikuti oleh kategori ukuran menengah (Medium Size App) dengan proporsi sebesar 34,8%, dan kategori ukuran besar (Big Size App) dengan proporsi sebesar 13,7%. Hal ini menunjukkan bahwa mayoritas aplikasi dalam dataset memiliki ukuran yang relatif kecil, diikuti oleh aplikasi dengan ukuran menengah dan besar.

# %%
# Korelasi antara User Rating dan Kategori Ukuran Aplikasi dalam Box Plot menggunakan Plotly Express
fig = px.box(df, x='SizeCatg', y='user_rating_ver', color='SizeCatg',
             title='Persebaran Rating Berdasarkan Ukuran Aplikasi',
             labels={'SizeCatg': 'Kategori Ukuran Aplikasi', 'user_rating_ver': 'User Rating (Max = 5)'},
             template='plotly_white')

colors = ['mediumaquamarine', 'mediumseagreen',  'seagreen']
fig.update_traces(marker=dict(color=colors[0]), selector=dict(name='Small Size App'))
fig.update_traces(marker=dict(color=colors[1]), selector=dict(name='Medium Size App'))
fig.update_traces(marker=dict(color=colors[2]), selector=dict(name='Big Size App'))

# Menampilkan box plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Penjelasan Visualisasi diatas** :
# 1. Ukuran aplikasi yang besar menunjukan konsentrasi penilaian rating dari pengguna terpusat pada rentang penilaian 3.5 - 4.5 dengan rata-rata pengguna memberikan penilaian **rating 4.0** dari skala maksimal 5.
#
# 2. Ukuran aplikasi yang sedang menunjukan konsentrasi penilaian rating dari pengguna terpusat pada rentang penilaian 3.0 - 4.5 dengan rata-rata pengguna memberikan penilaian **rating 4.0** dari skala maksimal 5.
#
# 3. Ukuran aplikasi yang kecil menunjukan konsentrasi penilaian rating dari pengguna terpusat pada rentang penilaian 1.0 - 4.5 dengan rata-rata pengguna memberikan penilaian **rating 4.0** dari skala maksimal 5.
#
# **Insight :**
#
# 1. Bedasarkan visualisasi diatas kita mengetahui bahwa **semakin besar ukuran aplikasi** maka penilaian **rating** yang diberikan pengguna akan terkonsentrasi untuk memberikan **penilaian yang baik** (terkonsetrasi pada rentang 3.5 s.d 4.5)
#
# 2. Di sisi lain, **semakin kecil ukuran aplikasi**, maka penilaian **rating** yang diberikan pengguna akan semakin tersebar dimana rating yang diberikan akan **sangat beragam** (tersebar pada rentang 1.0 s.d 4.5)
#
# Dengan memperhatikan jenis kategori **ukuran aplikasi**, ditemukan bahwa hampir semua aplikasi dari ketiga kategori ukuran aplikasi tersebut memberikan **penilaian rating pengguna** sebesar **4.0/5.0.**
#
# Hal ini menunjukan bahwa mayoritas aplikasi yang terdaftar pada Mobile App Store tersebut dipandang baik oleh pengguna App Store, meskipun terdapat beberapa outlier, dimana memiliki nilai rating yang lebih rendah daripada mayoritas aplikasi lainnya serta menunjukkan adanya variasi dalam kualitas aplikasi yang tersedia, di mana beberapa aplikasi mungkin tidak memenuhi harapan atau preferensi pengguna.

# %%
# Pembuatan kolom baru 'PriceCatg'/ Price Category dan inisialisasi dengan harga aplikasi dalam string
df['PriceCatg'] = df['price'].astype(str)

# Proses pengklasifikasian aplikasi berdasarkan harga
for i in range(len(df['PriceCatg'])):
    if df.loc[i, 'price'] < 0.1:
        df.loc[i, 'PriceCatg'] = 'Gratis'
    elif df.loc[i, 'price'] >= 0.1 and df.loc[i, 'price'] < 10:
        df.loc[i, 'PriceCatg'] = 'Berbayar Murah'
    elif df.loc[i, 'price'] >= 10 and df.loc[i, 'price'] <= 50:
        df.loc[i, 'PriceCatg'] = 'Berbayar Sedang'
    elif df.loc[i, 'price'] > 50:
        df.loc[i, 'PriceCatg'] = 'Berbayar Mahal'

# Mengubah klasifikasi ke format category
df['PriceCatg'] = pd.Categorical(df['PriceCatg'], categories=['Gratis', 'Berbayar Murah', 'Berbayar Sedang', 'Berbayar Mahal'], ordered=True)

# Total masing-masing kategori harga aplikasi
summary_stats = df['PriceCatg'].value_counts()
print(summary_stats)
# Out:
# PriceCatg
# Gratis             4056
# Berbayar Murah     3044
# Berbayar Sedang      90
# Berbayar Mahal        7
# Name: count, dtype: int64

# %%
# Menampilkan ringkasan statistik deskriptif dari kolom price
print("Ringkasan statistik deskriptif dari kolom price:")
print(df['price'].describe())
# Out:
# Ringkasan statistik deskriptif dari kolom price:
# count    7197.000000
# mean        1.726218
# std         5.833006
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.990000
# max       299.990000
# Name: price, dtype: float64

# %% [markdown]
# Dari dataset iOS App Store 2017, diketahui bahwa mayoritas aplikasi merupakan aplikasi gratis dengan jumlah 4.056 aplikasi terdaftar sedangkan harga aplikasi termahal adalah $299.9 USD.

# %%
# Korelasi antara Harga Aplikasi dan Kategori Ukuran Aplikasi dalam Box Plot menggunakan Plotly Express
fig = px.box(df, x='SizeCatg', y='price', color='SizeCatg',
             title='Persebaran Harga Berdasarkan Ukuran Aplikasi',
             labels={'SizeCatg': 'Kategori Ukuran Aplikasi', 'price': 'Harga Aplikasi (dalam satuan $USD)'},
             template='plotly_white')

colors = ['mediumaquamarine', 'mediumseagreen',  'seagreen']
fig.update_traces(marker=dict(color=colors[0]), selector=dict(name='Small Size App'))
fig.update_traces(marker=dict(color=colors[1]), selector=dict(name='Medium Size App'))
fig.update_traces(marker=dict(color=colors[2]), selector=dict(name='Big Size App'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1. Dari data diatas diketahui bahwa mayoritas aplikasi terdaftar adalah aplikasi gratis dengan jumlah 4.056 aplikasi terdaftar.
#
# 2. Di kategori aplikasi berbayar, terdapat 3.044 aplikasi berbayar murah (<10 USD), 90 aplikasi berbayar sedang (10 USD - 50 USD) dan 7 aplikasi berbayar mahal (>50 USD).

# %%
# Korelasi antara User Rating, Kategori Ukuran Aplikasi dan Price dalam Box Plot menggunakan Plotly Express
fig = px.box(df, x='PriceCatg', y='user_rating_ver', color='SizeCatg',
             title='Persebaran User Pada Versi App Store 2017',
             labels={'PriceCatg': 'Kategori Harga Aplikasi', 'user_rating_ver': 'User Rating (Max = 5)'},
             template='plotly_white')

colors = ['mediumaquamarine', 'olivedrab', 'seagreen']
fig.update_traces(marker=dict(color=colors[0]), selector=dict(name='Small Size App'))
fig.update_traces(marker=dict(color=colors[1]), selector=dict(name='Medium Size App'))
fig.update_traces(marker=dict(color=colors[2]), selector=dict(name='Big Size App'))
# Menampilkan box plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Dari hasil diatas kita dapat melihat bahwa aplikasi di :
# 1. kategori berbayar murah (<10 USD) dalam semua ukuran aplikasi (besar,sedang,kecil) memiliki penilaian rating terbaik dari pengguna, dimana rating penilaian terkonsentrasi pada rentang 3.0-4.5 dari skala 5.0.
#
# 2. Akan tetapi hal yang sama tidak dapat dikatakan untuk **kategori ukuran aplikasi** dan **kategori harga lainnya** dikarenakan baik untuk aplikasi yang **gratis** maupun **berbayar sedang dan mahal** memiliki respon feedback penilaian yang **cukup beragam dalam rentang penilaiannya.**

# %%
# Analisis Data Menggunakan Count Plot untuk Jumlah Aplikasi Berdasarkan Kategori Genre
color_palette = 'summer'

plt.figure(figsize=(10, 6))
ax = sns.countplot(y='prime_genre', data=df, palette=color_palette, hue='prime_genre', order=df['prime_genre'].value_counts().index)

for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width() + 0.1, p.get_y() + p.get_height() / 2), ha='left', va='center')

plt.title('Jumlah Aplikasi iOS App Store Berdasarkan Kategori', fontsize=16)
plt.xlabel('Jumlah', fontsize=12)
plt.ylabel('Genre Aplikasi', fontsize=12)

plt.show()

# %% [markdown]
# Berdasarkan hasil visualisasi Count Plot di atas menggambarkan sebaran jumlah aplikasi yang beredar pada ios Apps Store berdasarkan kategorinya. Semakin banyak suatu aplikasi muncul dalam suatu kategori semakin ke kanan arah yang ditunjukkan, sedangkan semakin sedikit akan semakin ke kiri arahnya. Ternyata aplikasi berkategori “GAMES” yang banyak beredar di ios Apps Store dengan jumlah aplikasi mencapai 3862, sedangkan aplikasi kecantikan “CATALOG” merupakan yang paling sedikit dengan jumlah 10 aplikasi.
#
# **Insight:**
#
# * Aplikasi kategori games memiliki jumlah 6x lipat dari kategori Entertainment di peingkat kedua dengan jumlah 500an aplikasi terdaftar.
#
# * Tiga aplikasi dengan jumlah terbanyak dan melebihi rata-rata di App Store adalah aplikasi dengan kategori genre “Games”, “Entertainment” dan “Education”.

# %%
# Korelasi Menggunakan Heatmap/Matriks Plot
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cbar=True, cmap="Greens")
plt.gcf().set_size_inches(15, 10)
plt.show()

# %% [markdown]
# Berdasarkan hasil visualisasi korelasi Heatmap di atas, terlihat bahwa setiap variabel memiliki nilai yang menggambarkan hubungannya dengan variabel lainnya. Sebagai contoh, variabel Size_bytes menunjukkan korelasi yang signifikan dengan user_rating_ver. Hal ini sesuai dengan analisis korelasi yang telah dilakukan sebelumnya. Dengan demikian, dapat disimpulkan bahwa ukuran aplikasi (Size_bytes) memiliki pengaruh yang cukup kuat terhadap nilai rata-rata peringkat pengguna untuk versi saat ini (user_rating_ver).

# %% [markdown]
# ####**KESIMPULAN**
#
# **- Ukuran Aplikasi**
#
# 1. Dari dataset iOS App Store 2017 terdapat 7.197 aplikasi seluler (mobile apps) yang terdaftar, dimana jumlah aplikasi dengan ukuran kecil (<100 Mb) memiliki jumlah terbesar dengan 3.702 aplikasi terdaftar sedangkan aplikasi dengan ukuran besar (>300 MB) memiliki jumlah terkecil dengan 989 aplikasi terdaftar.
#
# 2. Kita mengetahui bahwa semakin besar ukuran aplikasi maka penilaian rating yang diberikan pengguna akan terkonsentrasi untuk memberikan penilaian yang baik (terkonsetrasi pada rentang 3.5 s.d 4.5)
#
# 3. Dengan memperhatikan jenis kategori ukuran aplikasi, ditemukan bahwa hampir semua aplikasi dari ketiga kategori ukuran aplikasi memberikan penilaian rating pengguna sebesar 4.0/5.0. Hal ini menunjukan bahwa mayoritas aplikasi yang terdaftar dipandang baik oleh pengguna App Store, meskipun terdapat beberapa outlier dimana mendapatkan nilai yang lebih rendah daripada keseluruhan rentang penilaian grup.
#
#
# **- Harga Aplikasi**
# 1. Dari data diatas diketahui bahwa mayoritas aplikasi terdaftar adalah aplikasi gratis dengan jumlah 4.056 aplikasi terdaftar.
#
# 2. Di kategori aplikasi berbayar, terdapat 3.044 aplikasi berbayar murah (<10 USD), 90 aplikasi berbayar sedang (10 USD - 50 USD) dan 7 aplikasi berbayar mahal (>50 USD).
#
#
# **- Penilaian Rating**
#
# Penilaian rating dari pengguna secara konsisten mencatatkan rekam jejak yang baik untuk ukuran aplikasi besar (>300MB) untuk setiap kategori konten usia aplikasi dengan besaran rentang penilaian lebih besar dari 3.5 dalam skala 5.0.
#
#
#
# **- Kategori Genre Aplikasi**
#
# 1. Aplikasi kategori games memiliki jumlah 6x lipat dari kategori Entertainment di peingkat kedua dengan jumlah 500an aplikasi terdaftar.
#
# 2. Tiga aplikasi dengann jumlah terbanyak dan melebihi rata-rata di App Store adalah aplikasi dengan kategori genre “Games”, “Entertainment” dan “Education”.
#
# Untuk variabel yang saya visualisasikan kali ini cukup sampai disini saja meskipun masih terdapat beberapa variabel korelasi lainnya yang mungkin masih bisa dicoba untuk divisualisasikan, tetapi dari saya cukup memvisualisasikan sampai disini karena untuk variabel yang saya pilih merupakan yang paling umum biasanya dijadikan pertimbangan oleh pengguna maupun developer.

# %% [markdown]
# ##**Verify Data Quality**

# %% [markdown]
# ####Missing Values

# %%
# Mendeteksi nilai NaN/Null (Kosong) pada DataFrame Appstore (Cara 1)
nan_count = df.isna().sum()

# Menampilkan jumlah nilai NaN/Null (Kosong) untuk setiap kolom
print("Jumlah nilai NaN untuk setiap kolom:")
print(nan_count)
# Out:
# Jumlah nilai NaN untuk setiap kolom:
# Unnamed: 0          0
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# size_mb             0
# SizeCatg            0
# PriceCatg           0
# dtype: int64

# %% [markdown]
# Dari output diatas, terlihat jika semua kolom memiliki nilai null/NaN yang sama yaitu 0. Jika Null/NaN adalah 0, itu berarti tidak ada data yang hilang atau kosong dalam kolom tersebut. Artinya, setiap baris dalam kolom memiliki nilai yang valid atau terisi.

# %%
#Mengecek apakah ada nilai null di dataset atau tidak (Cara 2)
df.isnull().any()
# Out:
# Unnamed: 0          False
# id                  False
# track_name          False
# size_bytes          False
# currency            False
# price               False
# rating_count_tot    False
# rating_count_ver    False
# user_rating         False
# user_rating_ver     False
# ver                 False
# cont_rating         False
# prime_genre         False
# sup_devices.num     False
# ipadSc_urls.num     False
# lang.num            False
# vpp_lic             False
# size_mb             False
# SizeCatg            False
# PriceCatg           False
# dtype: bool

# %% [markdown]
# **df.isnull().any()** digunakan untuk memeriksa apakah terdapat nilai null (kosong) dalam setiap kolom dari DataFrame `df`. any() digunakan untuk mengidentifikasi apakah setidaknya satu nilai null (True) terdapat dalam setiap kolom DataFrame.
#
# Jika terdapat nilai null dalam suatu kolom, maka nilai kembalian untuk kolom tersebut akan menjadi True, sedangkan jika tidak terdapat nilai null, maka nilai kembalian akan menjadi False. Dalam contoh di atas, output menunjukkan bahwa tidak ada nilai null dalam setiap kolom dari DataFrame `df`, karena semua nilai kembalian adalah False. Dengan demikian, dapat disimpulkan bahwa tidak ada nilai yang hilang (missing values) dalam dataset tersebut.

# %% [markdown]
# ####Outliers Values

# %%
outlier_results = []

for column in df.columns:
    if df[column].dtype in ['float64', 'int64']:  # Hanya mengambil kolom dengan tipe data numerik
        q1 = df[column].quantile(0.25)            # Menghitung nilai kuartil
        q3 = df[column].quantile(0.75)            # Menghitung nilai kuartil
        iqr = q3 - q1                             # Menghitung rentang interquartile (IQR)
        bts_bwh = q1 - 1.5 * iqr                  # Menghitung batas bawah dan batas atas untuk outlier
        bts_ats = q3 + 1.5 * iqr
        outliers = df[(df[column] < bts_bwh) | (df[column] > bts_ats)]    # Mencari outlier dalam kolom
        percent_outliers = (len(outliers) / len(df)) * 100                # Menghitung persentase outlier
        outlier_results.append({'Kolom': column, 'Persentase Outliers': percent_outliers})

# Membuat dataframe dari list hasil
outlier_df = pd.DataFrame(outlier_results)
outlier_df.set_index('Kolom', inplace=True)

display(outlier_df)
# Out:
#                   Persentase Outliers
# Kolom
# Unnamed: 0                   0.000000
# id                           0.000000
# size_bytes                  10.810060
# price                       11.560372
# rating_count_tot            17.104349
# rating_count_ver            14.742254
# user_rating                 14.297624
# user_rating_ver              0.000000
# sup_devices.num             27.441990
# ipadSc_urls.num              0.000000
# lang.num                     5.946922
# vpp_lic                      0.694734
# size_mb                     10.810060

# %% [markdown]
# Tabel di atas menggambarkan persentase outlier dalam setiap kolom dataset. Berikut adalah penjelasan untuk setiap kolom:
#
# 1. **Unnamed: 0**: Tidak ada outlier dalam kolom ini, menunjukkan bahwa tidak ada indeks data yang secara signifikan berbeda dari yang lain.
#
# 2. **id**: Tidak ada outlier dalam kolom ini, menunjukkan bahwa tidak ada ID aplikasi yang secara signifikan berbeda dari yang lain.
#
# 3. **size_bytes**: Terdapat outlier sebesar 10.81% dalam kolom ini, menunjukkan bahwa ada beberapa nilai ukuran aplikasi dalam bytes yang berbeda secara signifikan dari yang lain.
#
# 4. **price**: Terdapat outlier sebesar 11.56% dalam kolom ini, menunjukkan bahwa ada beberapa nilai harga aplikasi yang berbeda secara signifikan dari yang lain.
#
# 5. **rating_count_tot**: Terdapat outlier sebesar 17.10% dalam kolom ini, menunjukkan bahwa ada beberapa nilai jumlah total peringkat pengguna yang berbeda secara signifikan dari yang lain.
#
# 6. **rating_count_ver**: Terdapat outlier sebesar 14.74% dalam kolom ini, menunjukkan bahwa ada beberapa nilai jumlah peringkat pengguna untuk versi saat ini yang berbeda secara signifikan dari yang lain.
#
# 7. **user_rating**: Terdapat outlier sebesar 14.30% dalam kolom ini, menunjukkan bahwa ada beberapa nilai rata-rata peringkat pengguna untuk semua versi yang berbeda secara signifikan dari yang lain.
#
# 8. **user_rating_ver**: Tidak ada outlier dalam kolom ini, menunjukkan bahwa tidak ada data nilai rata-rata peringkat pengguna untuk versi saat ini yang berbeda secara signifikan dari yang lain.
#
# 9. **sup_devices.num**: Terdapat outlier sebesar 27.44% dalam kolom ini, menunjukkan bahwa ada beberapa nilai jumlah perangkat pendukung yang berbeda secara signifikan dari yang lain.
#
# 10. **ipadSc_urls.num**: Tidak ada outlier dalam kolom ini, menunjukkan bahwa tidak ada data jumlah URL screenshot yang berbeda secara signifikan dari yang lain.
#
# 11. **lang.num**: Terdapat outlier sebesar 5.95% dalam kolom ini, menunjukkan bahwa ada beberapa nilai jumlah bahasa yang didukung yang berbeda secara signifikan dari yang lain.
#
# 12. **vpp_lic**: Terdapat outlier sebesar 0.69% dalam kolom ini, menunjukkan bahwa ada beberapa nilai status lisensi berbasis perangkat VPP yang berbeda secara signifikan dari yang lain.
#
# 13. **size_mb**: Terdapat outlier sebesar 10.81% dalam kolom ini, menunjukkan bahwa ada beberapa nilai ukuran aplikasi dalam megabyte yang berbeda secara signifikan dari yang lain.

# %% [markdown]
# ####Duplicated Values

# %%
#Tambahkan kode untuk mengecek apakah ada nilai duplikat pada tiap kolom di dataset kalian ya
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7192    False
# 7193    False
# 7194    False
# 7195    False
# 7196    False
# Length: 7197, dtype: bool

# %% [markdown]
# Berdasarkan hasil dari analisis awal serta output diatas, dapat disimpulkan bahwa data tersebut menunjukkan kualitas yang baik karena tidak mengandung nilai yang kosong atau duplikat. Sehingga, dataset ini tidak memerlukan tindakan lebih lanjut terkait dengan duplikasi data.

# %% [markdown]
# ####Inconsistent Values / Noise (Optional)

# %%
[print(f"Columns -> {col}\n{df[col].unique()}\n{'-' * 30}\n") for col in df.columns]
# Out:
# Columns -> Unnamed: 0
# [    1     2     3 ... 11087 11089 11097]
# ------------------------------
#
# Columns -> id
# [ 281656475  281796108  281940292 ... 1187779532 1187838770 1188375727]
# ------------------------------
#
# Columns -> track_name
# ['PAC-MAN Premium' 'Evernote - stay organized'
#  'WeatherBug - Local Weather, Radar, Maps, Alerts' ...
#  'Bret Michaels Emojis + Lyric Keyboard'
#  'VR Roller Coaster World - Virtual Reality'
#  'Escape the Sweet Shop Series']
# ------------------------------
#
# Columns -> size_bytes
# [100788224 158578688 100524032 ... 111322112  97235968  90898432]
# ------------------------------
#
# Columns -> currency
# ['USD']
# ------------------------------
#
# Columns -> price
# [  3.99   0.     0.99   9.99   4.99   7.99   2.99   1.99   5.99  12.99
#   21.99 249.99   6.99  74.99  19.99   8.99  24.99  13.99  14.99  16.99
#   47.99  11.99  59.99  15.99  27.99  17.99 299.99  49.99  23.99  20.99
#   39.99  99.99  29.99  34.99  18.99  22.99]
# ...

# %% [markdown]
# Tidak terlihat adanya nilai yang inkonsisten atau noise yang dapat diamati secara langsung dari output tersebut. Semua kolom memiliki nilai yang sesuai dengan jenis data yang diharapkan, tanpa adanya anomali yang mencolok.

# %% [markdown]
# #**DATA PREPARATION**

# %% [markdown]
# ##**Data Cleaning**

# %% [markdown]
# ###**Penanganan Missing Values**

# %% [markdown]
# #####**Pengecekkan Missing Values**

# %% [markdown]
# Berikut adalah hasil dalam bentuk persentase, yang dapat menjadi panduan dalam menentukan tindakan yang akan diambil terhadap nilai yang kosong.

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Unnamed: 0          0.0
# id                  0.0
# track_name          0.0
# size_bytes          0.0
# currency            0.0
# price               0.0
# rating_count_tot    0.0
# rating_count_ver    0.0
# user_rating         0.0
# user_rating_ver     0.0
# ver                 0.0
# cont_rating         0.0
# prime_genre         0.0
# sup_devices.num     0.0
# ipadSc_urls.num     0.0
# lang.num            0.0
# vpp_lic             0.0
# size_mb             0.0
# SizeCatg            0.0
# PriceCatg           0.0
# dtype: float64

# %% [markdown]
# Hasil pengecekan tersebut menunjukkan bahwa tidak ada nilai yang hilang dalam DataFrame. Semua kolom telah terisi dengan lengkap, sehingga tidak ditemukan kebutuhan untuk menangani atau mengisi nilai yang hilang dalam tahap pra-pemrosesan data.

# %% [markdown]
# ###**Penanganan Duplicated Values**

# %% [markdown]
# #####**Pengecekkan Nilai Duplikat**

# %%
duplicate_rows=df[df.duplicated()]

# %%
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, track_name, size_bytes, currency, price, rating_count_tot, rating_count_ver, user_rating, user_rating_ver, ver, cont_rating, prime_genre, sup_devices.num, ipadSc_urls.num, lang.num, vpp_lic, size_mb, SizeCatg, PriceCatg]
# Index: []

# %% [markdown]
# Hasil pengecekan menunjukkan bahwa tidak ada baris yang dianggap sebagai duplikat dalam dataset. Dalam outputnya, tidak ada baris yang terdaftar karena tidak ada duplikasi yang ditemukan. Ini menunjukkan bahwa setiap baris dalam dataset memiliki keunikan sendiri dan tidak ada yang sama persis dengan yang lain.

# %% [markdown]
# ###**Penanganan Outliers**

# %% [markdown]
# #####**Pengecekkan Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# Unnamed: 0                   0.000000
# id                           0.000000
# size_bytes                  10.810060
# price                       11.560372
# rating_count_tot            17.104349
# rating_count_ver            14.742254
# user_rating                 14.297624
# user_rating_ver              0.000000
# sup_devices.num             27.441990
# ipadSc_urls.num              0.000000
# lang.num                     5.946922
# vpp_lic                      0.694734
# size_mb                     10.810060

# %% [markdown]
# Output tersebut menampilkan persentase outliers untuk setiap kolom dalam dataset. Jika persentase outliers rendah (dekat dengan nol), artinya mayoritas data berada dalam kisaran yang normal. Namun, jika persentase outliers tinggi, maka bisa menandakan bahwa beberapa data dalam kolom memiliki nilai yang sangat ekstrem.

# %%
boxplot = df.drop('id', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# Berdasarkan grafik diatas, terlihat pola persebaran data atau nilai outliers. Bisa dilihat jika kolom 'size_bytes' memiliki nilai outliers yang terlihat sebagai titik-titik di luar "whiskers" (jangkauan didalam box plot) atau jauh dari Q1 dan Q3. Outliers ini menunjukkan adanya nilai-nilai yang sangat berbeda dari mayoritas data dalam kolom 'size_bytes'.

# %% [markdown]
# #####**Imputasi Outliers**

# %% [markdown]
# Melakukan flooring dan capping pada kolom "size_bytes"

# %%
Q1 = df['size_bytes'].quantile(0.25)
Q3 = df['size_bytes'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
df['size_bytes']=np.where(df['size_bytes']>upper_whisker,upper_whisker,np.where(df['size_bytes']<lower_whisker,lower_whisker,df['size_bytes']))

# %% [markdown]
# Proses diatas dilakukan untuk mengatasi outliers dalam data. Proses ini dilakukan dengan menggunakan kuartil pertama (Q1) dan kuartil ketiga (Q3) untuk menghitung rentang antarkuartil (IQR). Nilai batas bawah (lower_whisker) dan batas atas (upper_whisker) kemudian dihitung menggunakan IQR dan faktor pemanjangan 1.5. Nilai-nilai di bawah batas bawah akan diganti dengan batas bawah itu sendiri, sementara nilai-nilai di atas batas atas akan diganti dengan batas atasnya.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom             Persentase Outliers
# Unnamed: 0                   0.000000
# id                           0.000000
# size_bytes                   0.000000
# price                       11.560372
# rating_count_tot            17.104349
# rating_count_ver            14.742254
# user_rating                 14.297624
# user_rating_ver              0.000000
# sup_devices.num             27.441990
# ipadSc_urls.num              0.000000
# lang.num                     5.946922
# vpp_lic                      0.694734
# size_mb                     10.810060

# %% [markdown]
# Data di atas menunjukkan bahwa nilai-nilai ekstrim dalam kolom 'size_bytes' telah diubah menjadi 0. Setelah dilakukan pengecekan kembali, tidak ditemukan lagi nilai ekstrim dalam kolom tersebut. Ini dapat disebabkan oleh proses perubahan nilai ekstrim sebelumnya menggunakan metode flooring dan capping. Dengan demikian, kolom 'size_bytes' telah berhasil diolah sehingga tidak lagi memiliki nilai ekstrim setelah proses tersebut dilakukan.

# %%
boxplot = df.drop('id', axis=1).boxplot(grid=False, rot=45, figsize=(8,6))

# %%
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name   size_bytes currency  \
# 0                                       PAC-MAN Premium  100788224.0      USD
# 1                             Evernote - stay organized  158578688.0      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts  100524032.0      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...  128512000.0      USD
# 4                                                 Bible   92774400.0      USD
# ...                                                 ...          ...      ...
# ...

# %% [markdown]
# Grafik di atas menggambarkan penyebaran data atau nilai outliers dalam dataset, dengan fokus pada kolom 'size_bytes'. Terlihat bahwa setelah melakukan penanganan outliers, penyebaran data telah teratasi dengan baik, terutama pada kolom 'size_bytes'. Grafik menunjukkan bahwa tidak ada nilai yang jauh dari nilai-nilai lainnya, yang menunjukkan bahwa tidak ada lagi outliers yang signifikan dalam kolom 'size_bytes'. Hal ini menunjukkan bahwa proses penanganan outliers, seperti flooring and capping, telah berhasil dalam mengatasi nilai-nilai ekstrim dalam kolom 'size_bytes', sehingga distribusi datanya menjadi lebih merata dan dapat diinterpretasikan dengan lebih baik.

# %% [markdown]
# ##**Construct Data**

# %% [markdown]
# ###**Melakukan Rekayasa Fitur (Feature Engineering)**

# %%
def categorize_Urating(score):
    if score < 2.5:
        return 'Rendah'
    elif 2.5 <= score < 4.0:
        return 'Sedang'
    elif 4.0 <= score <= 5.0:
        return 'Tinggi'
    else:
        return 'Not Valid Score'

df['user_rating'] = df['user_rating'].apply(categorize_Urating)

# UNTUK PRIME GENRE

# Dictionary yang berisi jumlah aplikasi untuk setiap genre
genre_counts = {
    'Games': 3862, 'Entertainment': 535, 'Education': 453, 'Photo & Video': 349,
    'Utilities': 248, 'Health & Fitness': 180, 'Productivity': 178, 'Social Networking': 167,
    'Lifestyle': 144, 'Music': 138, 'Shopping': 122, 'Sports': 114, 'Book': 112,
    'Finance': 104, 'Travel': 81, 'News': 75, 'Weather': 72, 'Reference': 64,
    'Food & Drink': 63, 'Business': 57, 'Navigation': 46, 'Medical': 23, 'Catalogs': 10
}

# Mapping kategori berdasarkan jumlah aplikasi
def categorize_genre(count):
    if count >= 3000:
        return 'Very Popular'
    elif 2000 <= count < 3000:
        return 'Popular'
    elif 1000 <= count < 2000:
        return 'Moderate'
    elif 500 <= count < 1000:
        return 'Less Popular'
    elif 10 <= count < 500:
        return 'Niche'
    else:
        return 'Unknown'

df['prime_genre'] = df['prime_genre'].map(genre_counts).apply(categorize_genre)

# %% [markdown]
# Setelah melakukan analisis pada dataset ini, ditemukan kebutuhan akan penyesuaian fitur tambahan dalam rangka meningkatkan kualitas analisis dan kinerja model.Sebagai upaya memperbaiki hal tersebut, telah dilakukan upaya rekayasa fitur (Feature Engineering) untuk kolom **size_bytes** dan **price** tetapi hal itu telah saya buat dalam pertemuan sebelumnya saat memvisualisasikan data. Tetapi selain itu terdapat pula rekayasa fitur lainnya yakni untuk kolom **user_rating** dan **prime_genre**
#
#
# Kolom size_bytes sendiri telah dikategorikan menjadi **SizeCatg** yang terdiri dari tiga kategori, yaitu (Small, Medium, dan Big) sementara kolom price menjadi **PriceCatg** dan  terbagi menjadi empat kategori yakni (Gratis, Berbayar Murah, Berbayar Sedang dan Berbayar Mahal), untuk kolom **user_rating** sendiri dikategorikan menjadi (Rendah, Sedang, Tinggi) dan untuk kategori terakhir yakni kolom **prime_genre** berisi 4 kategori diantaranya (Niche, Less Popular, Moderate, Popular, Very Popular) Rekayasa fitur tambahan ini diharapkan dapat memperkaya informasi yang tersedia, memfasilitasi analisis yang lebih mendalam, serta meningkatkan kinerja model pada data yang dihadapi.

# %%
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name   size_bytes currency  \
# 0                                       PAC-MAN Premium  100788224.0      USD
# 1                             Evernote - stay organized  158578688.0      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts  100524032.0      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...  128512000.0      USD
# 4                                                 Bible   92774400.0      USD
# ...                                                 ...          ...      ...
# ...

# %% [markdown]
# #**Data Reduction**

# %% [markdown]
# ###**Mengurangi Fitur - Fitur Yang Kurang Relevan**

# %%
df_corr = df.corr(numeric_only=True)
px.imshow(df_corr)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name   size_bytes currency  \
# 0                                       PAC-MAN Premium  100788224.0      USD
# 1                             Evernote - stay organized  158578688.0      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts  100524032.0      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...  128512000.0      USD
# 4                                                 Bible   92774400.0      USD
# ...                                                 ...          ...      ...
# ...

# %%
df = df.drop(['track_name', 'cont_rating', 'ver', 'ipadSc_urls.num','vpp_lic','currency', ], axis=1)

# %%
df
# Out:
#       Unnamed: 0          id   size_bytes  price  rating_count_tot  \
# 0              1   281656475  100788224.0   3.99             21292
# 1              2   281796108  158578688.0   0.00            161065
# 2              3   281940292  100524032.0   0.00            188583
# 3              4   282614216  128512000.0   0.00            262241
# 4              5   282935706   92774400.0   0.00            985920
# ...          ...         ...          ...    ...               ...
# 7192       11081  1187617475  126644224.0   0.00               142
# 7193       11082  1187682390  120760320.0   0.00                30
# 7194       11087  1187779532  111322112.0   1.99                15
# 7195       11089  1187838770   97235968.0   0.00                85
# 7196       11097  1188375727   90898432.0   0.00                 3
#
#       rating_count_ver user_rating  user_rating_ver   prime_genre  \
# 0                   26      Tinggi              4.5  Very Popular
# ...

# %% [markdown]
# Penghapusan kolom dari dataset dilakukan karena :
#
# - Kolom "ipadSc_urls.num" dihapus karena tidak memberikan informasi yang signifikan atau relevan untuk analisis yang sedang dilakukan. Jumlah tangkapan layar tidak mempengaruhi pemahaman atau pemodelan fitur-fitur penting dalam dataset, sehingga penghapusan kolom ini dapat menyederhanakan dataset dan meningkatkan efisiensi analisis.
#
# - Kolom "vpp_lic" berisi nomor lisensi yang tidak memiliki hubungan dengan fokus penelitian atau analisis yang sedang dilakukan. Informasi ini tidak memberikan kontribusi yang signifikan terhadap pemahaman atau modelisasi data yang sedang dilakukan. Dengan demikian, kolom tersebut dihilangkan untuk menyederhanakan dataset dan fokus pada fitur-fitur yang lebih relevan.
#
# - Kolom "ver" dihapus karena nomor versi aplikasi tidak memiliki hubungan dengan fokus penelitian atau analisis yang sedang dilakukan. Informasi ini tidak memberikan kontribusi yang signifikan terhadap pemahaman atau modelisasi data yang sedang dilakukan. Dengan demikian, kolom tersebut dihilangkan untuk menyederhanakan dataset dan fokus pada fitur-fitur yang lebih relevan.
#
# -  "ipadSc_urls.num" dihapus karena tidak memberikan informasi yang signifikan atau relevan untuk analisis yang sedang dilakukan. Jumlah tangkapan layar tidak mempengaruhi pemahaman atau pemodelan fitur-fitur penting dalam dataset, sehingga penghapusan kolom ini dapat menyederhanakan dataset dan meningkatkan efisiensi analisis.
#
# - Kolom "track_name" dihapus karena nama-nama aplikasi tidak relevan dengan fokus penelitian atau analisis yang sedang dilakukan. Informasi ini tidak memberikan kontribusi yang signifikan terhadap pemahaman atau modelisasi data yang sedang dilakukan. Dengan demikian, kolom tersebut dihilangkan untuk menyederhanakan dataset dan fokus pada fitur-fitur yang lebih relevan.
#
# - Kolom "cont_rating" dihapus karena rating konten aplikasi tidak terlalu relevan dengan fokus penelitian atau analisis yang sedang dilakukan. Informasi ini tidak memberikan kontribusi yang signifikan terhadap pemahaman atau modelisasi data yang sedang dilakukan. Dengan demikian, kolom tersebut dihilangkan untuk menyederhanakan dataset dan fokus pada fitur-fitur yang lebih relevan.

# %% [markdown]
# ###**Pengecekkan Hasil**

# %% [markdown]
# #**Data Transformation**

# %% [markdown]
# ###**Mapping**

# %%
# UNTUK SIZE DAN PRICE
df['SizeCatg'] = df['SizeCatg'].map({'Small Size App': 0, 'Medium Size App': 1, 'Big Size App': 2}).astype(int)
df['PriceCatg'] = df['PriceCatg'].map({'Gratis': 0, 'Berbayar Murah': 1, 'Berbayar Sedang': 2, 'Berbayar Mahal': 3}).astype(int)

# UNTUK USER RATING
df['user_rating'] = df['user_rating'].map({'Rendah': 1, 'Sedang': 2, 'Tinggi': 3}).astype(int)

# UNTUK PRIME GENRE
# Mengonversi kategori menjadi nilai numerik
category_map = {'Very Popular': 5, 'Popular': 4, 'Moderate': 3, 'Less Popular': 2, 'Niche': 1, 'Unknown': 0}
df['prime_genre'] = df['prime_genre'].map(category_map)

# %% [markdown]
# <!-- ? -->

# %% [markdown]
# Mapping dilakukan untuk mengonversi nilai-nilai kategori dalam dataset menjadi representasi numerik. Dalam konteks ini, Kolom "SizeCatg" dan "PriceCatg" diubah menjadi nilai numerik untuk merepresentasikan kategori ukuran dan harga aplikasi. Ini memungkinkan analisis data yang lebih efisien dengan mengonversi kategori seperti 'Small Size App', 'Medium Size App', dan 'Big Size App' menjadi nilai 0, 1, dan 2 untuk ukuran aplikasi, serta 'Gratis', 'Berbayar Murah', 'Berbayar Sedang', dan 'Berbayar Mahal' menjadi nilai 0, 1, 2, dan 3 untuk harga aplikasi.
#
#
# Kolom "user_rating" diubah menjadi nilai numerik untuk merepresentasikan kategori rating pengguna, mengubah 'Rendah', 'Sedang', dan 'Tinggi' menjadi nilai 1, 2, dan 3. Sedangkan kolom "prime_genre" diubah menjadi nilai numerik untuk merepresentasikan kategori genre utama aplikasi, mengubah kategori seperti 'Very Popular', 'Popular', 'Moderate', 'Less Popular', 'Niche', dan 'Unknown' menjadi nilai 5, 4, 3, 2, 1, dan 0 secara berturut-turut. Hal ini memudahkan dalam analisis data dengan menyederhanakan representasi kategori-kategori tersebut menjadi angka-angka.

# %%
df
# Out:
#       Unnamed: 0          id   size_bytes  price  rating_count_tot  \
# 0              1   281656475  100788224.0   3.99             21292
# 1              2   281796108  158578688.0   0.00            161065
# 2              3   281940292  100524032.0   0.00            188583
# 3              4   282614216  128512000.0   0.00            262241
# 4              5   282935706   92774400.0   0.00            985920
# ...          ...         ...          ...    ...               ...
# 7192       11081  1187617475  126644224.0   0.00               142
# 7193       11082  1187682390  120760320.0   0.00                30
# 7194       11087  1187779532  111322112.0   1.99                15
# 7195       11089  1187838770   97235968.0   0.00                85
# 7196       11097  1188375727   90898432.0   0.00                 3
#
#       rating_count_ver  user_rating  user_rating_ver  prime_genre  \
# 0                   26            3              4.5            5
# ...

# %% [markdown]
# Tabel diatas merupakan hasil dari proses mapping nilai kategorikal ke nilai numerik dalam dataset. Setiap kolom yang sebelumnya berisi nilai kategorikal sekarang telah diubah menjadi nilai numerik sesuai dengan aturan yang ditetapkan dalam proses mapping.

# %% [markdown]
# ###**Encoding**

# %%
df = pd.get_dummies(df)

# %% [markdown]
# Code tersebut digunakan untuk mengonversi variabel kategorikal dalam DataFrame menjadi bentuk biner, di mana setiap nilai kategorikal menjadi kolom baru dengan nilai biner (0 atau 1), yang membantu dalam analisis dan pemodelan data.

# %% [markdown]
# ###**Pengecekkan Hasil**

# %%
df.head()
# Out:
#    Unnamed: 0         id   size_bytes  price  rating_count_tot  \
# 0           1  281656475  100788224.0   3.99             21292
# 1           2  281796108  158578688.0   0.00            161065
# 2           3  281940292  100524032.0   0.00            188583
# 3           4  282614216  128512000.0   0.00            262241
# 4           5  282935706   92774400.0   0.00            985920
#
#    rating_count_ver  user_rating  user_rating_ver  prime_genre  \
# 0                26            3              4.5            5
# 1                26            3              3.5            1
# 2              2822            2              4.5            1
# 3               649            3              4.5            1
# 4              5320            3              5.0            1
#
#    sup_devices.num  lang.num     size_mb  SizeCatg  PriceCatg
# 0               38        10  100.788224         1          1
# 1               37        23  158.578688         1          0
# ...

# %% [markdown]
# Tabel diatas merupakan hasil dari proses encoding yang dilakukan terhadap DataFrame awal. Setiap nilai kategorikal dalam DataFrame telah diubah menjadi kolom baru dengan nilai biner (0 atau 1). Kolom baru ini mewakili setiap nilai unik dalam variabel kategorikal asli. Jika suatu baris memiliki nilai tertentu dalam variabel kategorikal, maka kolom yang sesuai dengan nilai tersebut akan memiliki nilai 1, sedangkan kolom-kolom lainnya akan memiliki nilai 0.

# %%
df
# Out:
#       Unnamed: 0          id   size_bytes  price  rating_count_tot  \
# 0              1   281656475  100788224.0   3.99             21292
# 1              2   281796108  158578688.0   0.00            161065
# 2              3   281940292  100524032.0   0.00            188583
# 3              4   282614216  128512000.0   0.00            262241
# 4              5   282935706   92774400.0   0.00            985920
# ...          ...         ...          ...    ...               ...
# 7192       11081  1187617475  126644224.0   0.00               142
# 7193       11082  1187682390  120760320.0   0.00                30
# 7194       11087  1187779532  111322112.0   1.99                15
# 7195       11089  1187838770   97235968.0   0.00                85
# 7196       11097  1188375727   90898432.0   0.00                 3
#
#       rating_count_ver  user_rating  user_rating_ver  prime_genre  \
# 0                   26            3              4.5            5
# ...

# %%
df.to_csv("Data Cleaned.csv")

# %%
df
# Out:
#       Unnamed: 0          id   size_bytes  price  rating_count_tot  \
# 0              1   281656475  100788224.0   3.99             21292
# 1              2   281796108  158578688.0   0.00            161065
# 2              3   281940292  100524032.0   0.00            188583
# 3              4   282614216  128512000.0   0.00            262241
# 4              5   282935706   92774400.0   0.00            985920
# ...          ...         ...          ...    ...               ...
# 7192       11081  1187617475  126644224.0   0.00               142
# 7193       11082  1187682390  120760320.0   0.00                30
# 7194       11087  1187779532  111322112.0   1.99                15
# 7195       11089  1187838770   97235968.0   0.00                85
# 7196       11097  1188375727   90898432.0   0.00                 3
#
#       rating_count_ver  user_rating  user_rating_ver  prime_genre  \
# 0                   26            3              4.5            5
# ...

# %% [markdown]
# #**DATA MODELLING**

# %% [markdown]
# Modelling dalam dataset ini menggunakan Modelling Associate dan Modelling Predict.

# %% [markdown]
# ##**Inisiasi Variabel untuk menyimpan Dataframe**

# %%
df = pd.read_csv('/content/Data Cleaned.csv') #Dataframe yang telah dicleaning

# %%
# Drop kolom "Unnamed: 0"
df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'], inplace=True)
df
# Out:
#               id   size_bytes  price  rating_count_tot  rating_count_ver  \
# 0      281656475  100788224.0   3.99             21292                26
# 1      281796108  158578688.0   0.00            161065                26
# 2      281940292  100524032.0   0.00            188583              2822
# 3      282614216  128512000.0   0.00            262241               649
# 4      282935706   92774400.0   0.00            985920              5320
# ...          ...          ...    ...               ...               ...
# 7192  1187617475  126644224.0   0.00               142                75
# 7193  1187682390  120760320.0   0.00                30                30
# 7194  1187779532  111322112.0   1.99                15                 0
# 7195  1187838770   97235968.0   0.00                85                32
# 7196  1188375727   90898432.0   0.00                 3                 3
#
#       user_rating  user_rating_ver  prime_genre  sup_devices.num  lang.num  \
# ...

# %%
df = df.drop(['id', 'price', 'size_bytes', 'size_mb'], axis=1)

# %%
print(df.columns)
# Out:
# Index(['rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'prime_genre', 'sup_devices.num', 'lang.num',
#        'SizeCatg', 'PriceCatg'],
#       dtype='object')

# %% [markdown]
# ##**Modelling Associate**

# %% [markdown]
# ###**Pre-Processing**

# %% [markdown]
# #####**Adjusment**

# %%
x_final = df.drop('user_rating', axis=1)

# %%
x_final
# Out:
#       rating_count_tot  rating_count_ver  user_rating_ver  prime_genre  \
# 0                21292                26              4.5            5
# 1               161065                26              3.5            1
# 2               188583              2822              4.5            1
# 3               262241               649              4.5            1
# 4               985920              5320              5.0            1
# ...                ...               ...              ...          ...
# 7192               142                75              4.5            5
# 7193                30                30              4.5            5
# 7194                15                 0              0.0            1
# 7195                85                32              4.5            5
# 7196                 3                 3              5.0            5
#
#       sup_devices.num  lang.num  SizeCatg  PriceCatg
# 0                  38        10         1          1
# ...

# %% [markdown]
# Kolom "currency" dihapus karena informasi mata uang tidak memiliki hubungan dengan fokus penelitian atau analisis yang sedang dilakukan. Informasi ini tidak memberikan kontribusi yang signifikan terhadap pemahaman atau modelisasi data yang sedang dilakukan. Dengan demikian, kolom tersebut dihilangkan untuk menyederhanakan dataset dan fokus pada fitur-fitur yang lebih relevan.

# %% [markdown]
# #####**Normalisasi Data**

# %%
scaler = MinMaxScaler()

x_final_norm = scaler.fit_transform(x_final)

# %%
df
# Out:
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 0                21292                26            3              4.5
# 1               161065                26            3              3.5
# 2               188583              2822            2              4.5
# 3               262241               649            3              4.5
# 4               985920              5320            3              5.0
# ...                ...               ...          ...              ...
# 7192               142                75            3              4.5
# 7193                30                30            3              4.5
# 7194                15                 0            3              0.0
# 7195                85                32            3              4.5
# 7196                 3                 3            3              5.0
#
#       prime_genre  sup_devices.num  lang.num  SizeCatg  PriceCatg
# ...

# %% [markdown]
#  Normalisasi data merupakan tahap yang penting dalam analisis data untuk memastikan bahwa semua fitur memiliki rentang nilai yang serupa.

# %% [markdown]
# #####**Validasi Silang**

# %%
inertia_values = []

k_range = range(2, 10)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(x_final_norm)
    inertia_values.append(kmeans.inertia_)

plt.plot(k_range, inertia_values, marker='o')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal K')
plt.xticks(k_range)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# ...

# %% [markdown]
# Output tersebut dapat digunakan untuk menemukan titik di mana penambahan jumlah cluster tidak memberikan penurunan yang signifikan dalam inertia (jumlah total jarak kuadrat antara titik data dan pusat cluster terdekat).

# %% [markdown]
# ###**Build Model**

# %% [markdown]
# #####**K-MEANS**

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(x_final_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# KMeans(n_clusters=3, random_state=42)

# %% [markdown]
# Code tersebut bertujuan untuk membuat model KMeans dengan jumlah cluster sebanyak 4 dan melatihnya menggunakan data yang telah dinormalisasi.

# %% [markdown]
# #####**Hierarchical Clustering**

# %%
hc = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')

# %% [markdown]
# Code tersebut bertujuan untuk membuat model Hierarchical Clustering dengan menggunakan algoritma aglomeratif, yang kemudian dapat digunakan untuk mengelompokkan data ke dalam beberapa klaster berdasarkan jarak antara titik-titik data

# %% [markdown]
# ###**Begins and Compare Clusters**

# %%
kmeans_clust = kmeans.predict(x_final_norm)
hierarchy_clust = hc.fit_predict(x_final_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning:
#
# Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead

# %% [markdown]
# Code tersebut bertujuan untuk melakukan prediksi cluster untuk setiap titik data dalam dataset menggunakan model KMeans dan Hierarchical Clustering yang telah dibuat sebelumnya.

# %%
x_final = pd.DataFrame(x_final).reset_index(drop=True)

kmeans_col = pd.DataFrame(kmeans_clust, columns=["kmeans_cluster"])
hierarchy_col = pd.DataFrame(hierarchy_clust, columns=["hierarchy_cluster"])

combined_data_assoc = pd.concat([x_final, kmeans_col, hierarchy_col], axis=1)

# %% [markdown]
# Code tersebut bertujuan untuk menggabungkan prediksi cluster dari model KMeans dan Hierarchical Clustering dengan dataframe x_final yang telah direset indexnya, sehingga menghasilkan dataframe yang berisi data asli beserta prediksi cluster untuk setiap titik data.

# %%
combined_data_assoc.head()
# Out:
#    rating_count_tot  rating_count_ver  user_rating_ver  prime_genre  \
# 0             21292                26              4.5            5
# 1            161065                26              3.5            1
# 2            188583              2822              4.5            1
# 3            262241               649              4.5            1
# 4            985920              5320              5.0            1
#
#    sup_devices.num  lang.num  SizeCatg  PriceCatg  kmeans_cluster  \
# 0               38        10         1          1               0
# 1               37        23         1          0               2
# 2               37         3         1          0               2
# 3               37         9         1          0               2
# 4               37        45         0          0               2
#
#    hierarchy_cluster
# 0                  0
# 1                  1
# 2                  1
# 3                  1
# 4                  1

# %% [markdown]
# Menetapkan dataframe yang telah digabungkan, yaitu combined_data_assoc

# %% [markdown]
# #####**VISUALISASI ASOSIATIF**

# %%
# DALAM BENTUK HISTOGRAM

# Membuat dataframe sementara dengan kolom klaster
data_kmeans = combined_data_assoc.copy()
data_kmeans['kmeans_cluster'] = data_kmeans['kmeans_cluster'].astype(str)

data_hierarchy = combined_data_assoc.copy()
data_hierarchy['hierarchy_cluster'] = data_hierarchy['hierarchy_cluster'].astype(str)

# Menetapkan warna untuk setiap klaster
color_map_kmeans = {'2': 'grey', '3': 'grey', '1': 'skyblue', '5': 'grey', '4': 'grey', '0': 'grey'}
color_map_hierarchy = {'3': 'grey', '2': 'grey', '1': 'grey', '0': 'skyblue', '4': 'grey', '5': 'grey', }

# Histogram untuk hasil klastering dari K-Means
fig = px.histogram(data_kmeans, x='kmeans_cluster', title='Histogram of K-Means Clustering',
                   labels={'kmeans_cluster': 'Cluster', 'count': 'Frequency'}, color='kmeans_cluster',
                   color_discrete_map=color_map_kmeans)
fig.update_layout(xaxis=dict(dtick=1), bargap=0.1)
fig.show()

# Histogram untuk hasil klastering dari Hierarchical Clustering
fig = px.histogram(data_hierarchy, x='hierarchy_cluster', title='Histogram of Hierarchical Clustering',
                   labels={'hierarchy_cluster': 'Cluster', 'count': 'Frequency'}, color='hierarchy_cluster',
                   color_discrete_map=color_map_hierarchy)
fig.update_layout(xaxis=dict(dtick=1), bargap=0.1)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# DALAM BENTUK PIE CHART

# Menghitung jumlah setiap klaster
cluster_counts_kmeans = data_kmeans['kmeans_cluster'].value_counts(normalize=True) * 100
cluster_counts_hierarchy = data_hierarchy['hierarchy_cluster'].value_counts(normalize=True) * 100

# Plot pie untuk K-Means Clustering
fig = px.pie(names=cluster_counts_kmeans.index, values=cluster_counts_kmeans.values,
             title='Pie Chart of K-Means Clustering', labels={'names': 'Cluster', 'values': 'Percentage'})
fig.show()

# Plot pie untuk Hierarchical Clustering
fig = px.pie(names=cluster_counts_hierarchy.index, values=cluster_counts_hierarchy.values,
             title='Pie Chart of Hierarchical Clustering', labels={'names': 'Cluster', 'values': 'Percentage'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##**Modelling Predict**

# %% [markdown]
# ###**Pre-Processing**

# %% [markdown]
# #####**Split Data**

# %%
x = df.drop('user_rating', axis=1)
y = df['user_rating']

# x_train: fitur-fitur dari data latih
# x_test: fitur-fitur dari data uji
# y_train: variabel target dari data latih
# y_test: variabel target dari data uji

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# Code diatas merupakan proses pemisahan data (splitting data). Disini kolom 'user_rating' digunakan sebagai kolom target atau variabel yang ingin diprediksi. Proses ini juga bertujuan untuk memisahkan dataset menjadi data latih dan data uji serta memisahkan fitur-fitur dari variabel target. Tujuan dari pemisahan ini adalah untuk melatih model menggunakan data latih dan menguji kinerjanya menggunakan data uji, sehingga dapat dievaluasi seberapa baik model dapat melakukan prediksi pada data baru yang belum pernah dilihat sebelumnya.

# %%
x_test
# Out:
#       rating_count_tot  rating_count_ver  user_rating_ver  prime_genre  \
# 3592              1886                57              5.0            5
# 2178              1452               207              4.0            1
# 1760               104                54              4.0            5
# 5655                 1                 1              1.0            1
# 5944                 7                 0              0.0            5
# ...                ...               ...              ...          ...
# 3332                 8                 0              0.0            5
# 2029                 0                 0              0.0            1
# 6343                68                 8              1.5            5
# 6652                 0                 0              0.0            5
# 1423             47172                28              2.5            1
#
#       sup_devices.num  lang.num  SizeCatg  PriceCatg
# 3592               37         1         0          1
# ...

# %% [markdown]
# DataFrame diatas berisi fitur-fitur dari data uji yang akan digunakan untuk menguji kinerja model yang telah dilatih.

# %%
y_test
# Out:
# 3592    3
# 2178    3
# 1760    3
# 5655    1
# 5944    2
#        ..
# 3332    3
# 2029    1
# 6343    2
# 6652    1
# 1423    2
# Name: user_rating, Length: 1440, dtype: int64

# %% [markdown]
# DataFrame diatas berisi variabel target dari data uji yang akan digunakan untuk menguji kinerja model yang telah dilatih.

# %%
scaler = MinMaxScaler()

x_train_norm = scaler.fit_transform(x_train)

x_test_norm = scaler.transform(x_test)

# %% [markdown]
# Normalisasi adalah proses mengubah rentang nilai dari fitur-fitur dalam dataset sehingga memiliki skala yang seragam, yaitu antara 0 dan 1. Pada proses ini Min-Max Scaler digunakan untuk mengubah nilai-nilai dalam data latih (x_train) dan data uji (x_test) agar memiliki rentang yang sama. Tujuannya adalah agar dapat memastikan bahwa perbedaan skala antar fitur tidak memengaruhi kinerja model.

# %%
x_train_norm
# Out:
# array([[1.80930629e-02, 9.31940130e-04, 8.00000000e-01, ...,
#         1.33333333e-02, 0.00000000e+00, 3.33333333e-01],
#        [4.39789073e-02, 1.65845806e-01, 1.00000000e+00, ...,
#         2.66666667e-02, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.66666667e-02, 5.00000000e-01, 3.33333333e-01],
#        ...,
#        [1.05826651e-03, 1.86388026e-03, 9.00000000e-01, ...,
#         1.33333333e-02, 5.00000000e-01, 0.00000000e+00],
#        [1.14298162e-05, 1.92036148e-04, 7.00000000e-01, ...,
#         4.00000000e-02, 1.00000000e+00, 3.33333333e-01],
#        [6.67299565e-04, 2.25924880e-05, 1.00000000e+00, ...,
#         2.00000000e-01, 0.00000000e+00, 0.00000000e+00]])

# %% [markdown]
# Output diatas menampilkan data latih yang telah dinormalisasi

# %%
x_test_norm
# Out:
# array([[6.34018629e-04, 3.21942954e-04, 1.00000000e+00, ...,
#         1.33333333e-02, 0.00000000e+00, 3.33333333e-01],
#        [4.88120387e-04, 1.16916125e-03, 8.00000000e-01, ...,
#         1.86666667e-01, 0.00000000e+00, 0.00000000e+00],
#        [3.49617908e-05, 3.04998588e-04, 8.00000000e-01, ...,
#         4.00000000e-02, 1.00000000e+00, 3.33333333e-01],
#        ...,
#        [2.28596324e-05, 4.51849760e-05, 3.00000000e-01, ...,
#         1.33333333e-02, 5.00000000e-01, 3.33333333e-01],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         2.66666667e-02, 0.00000000e+00, 0.00000000e+00],
#        [1.58578615e-02, 1.58147416e-04, 5.00000000e-01, ...,
#         4.13333333e-01, 5.00000000e-01, 0.00000000e+00]])

# %% [markdown]
# Output diatas menampilkan data uji yang telah dinormalisasi

# %% [markdown]
# ###**Build and Train Model**

# %% [markdown]
# #####**Gaussian Naive Bayes**

# %%
gnb = GaussianNB()
gnb.fit(x_train_norm,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Code tersebut digunakan untuk menginisialisasi dan melatih model GNB untuk digunakan dalam suatu tugas klasifikasi atau prediksi berdasarkan data yang telah diberikan.

# %% [markdown]
# #####**K-Nearest Neighbor**

# %%
knn = KNeighborsClassifier()
knn.fit(x_train_norm, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Tujuan penggunaan algoritma ini adalah untuk memahami pola-pola yang ada dalam data latih untuk menghasilkan model yang dapat memprediksi label data baru berdasarkan kedekatannya dengan data yang telah dipelajari selama pelatihan.

# %% [markdown]
# #####**Decision Tree**

# %%
dtc = DecisionTreeClassifier()
dtc.fit(x_train_norm, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Code tersebut digunakan untuk menjalankan proses pelatihan model klasifikasi. Dimana nantinya model dapat memahami pola-pola dalam data latih dan mengonstruksi aturan-aturan keputusan yang terwakilkan dalam struktur pohon. Model yang terlatih kemudian dapat digunakan untuk memprediksi label dari data baru dengan menggunakan aturan-aturan yang ada dalam pohon keputusan yang telah dibangun.

# %% [markdown]
# ###**Begins and Compare Predict**

# %%
gnb_pred = gnb.predict(x_test_norm)
knn_pred = knn.predict(x_test_norm)
dtc_pred = dtc.predict(x_test_norm)

# %% [markdown]
# Code diatas digunakan untuk melakukan prediksi label dari data uji menggunakan model klasifikasi yang telah dilatih sebelumnya dengan algoritma Gaussian Naive Bayes (GNB), K-Nearest Neighbors (KNN), dan Decision Tree (DTC).

# %%
x_test = pd.DataFrame(x_test).reset_index(drop=True)
y_test = pd.DataFrame(y_test).reset_index(drop=True)

gnb_col = pd.DataFrame(gnb_pred.astype(int), columns=["gnb_prediction"])
knn_col = pd.DataFrame(knn_pred.astype(int), columns=["knn_prediction"])
dtc_col = pd.DataFrame(dtc_pred.astype(int), columns=["dtc_prediction"])

combined_data = pd.concat([x_test, y_test, gnb_col, knn_col, dtc_col], axis=1)

# %% [markdown]
# Code tersebut digunakan untuk membandingkan prediksi yang dihasilkan oleh tiga model klasifikasi yang berbeda (Gaussian Naive Bayes, K-Nearest Neighbors, dan Decision Tree) pada data uji (x_test) dan menampilkan hasil prediksi beserta label yang sebenarnya (y_test) dalam satu DataFrame yang tergabung. Jadi combined_data akan berisi data uji, variabel target, dan hasil prediksi dari ketiga model dalam satu dataset yang dapat digunakan untuk analisis lebih lanjut atau evaluasi kinerja model.

# %%
combined_data.head()
# Out:
#    rating_count_tot  rating_count_ver  user_rating_ver  prime_genre  \
# 0              1886                57              5.0            5
# 1              1452               207              4.0            1
# 2               104                54              4.0            5
# 3                 1                 1              1.0            1
# 4                 7                 0              0.0            5
#
#    sup_devices.num  lang.num  SizeCatg  PriceCatg  user_rating  \
# 0               37         1         0          1            3
# 1               38        14         0          0            3
# 2               43         3         2          1            3
# 3               38         8         0          0            1
# 4               40         1         2          1            2
#
#    gnb_prediction  knn_prediction  dtc_prediction
# 0               3               3               3
# 1               3               3               3
# ...

# %% [markdown]
# Output tersebut menampilkan data sampel dari dataframe combined_data

# %%
# from sklearn.tree import export_text
# from sklearn.tree import DecisionTreeClassifier
# from sklearn import tree
# import graphviz

# # Membuat model Decision Tree Classifier
# dtc = DecisionTreeClassifier()
# dtc.fit(x_train, y_train)

# # Membuat teks representasi pohon keputusan
# tree_rules = export_text(dtc, feature_names=x_train.columns.tolist())

# # Membuat visualisasi pohon keputusan dengan Graphviz
# dot_data = tree.export_graphviz(dtc, out_file=None,
#                                 feature_names=x_train.columns.tolist(),
#                                 class_names=class_names_str,
#                                 filled=True, rounded=True,
#                                 special_characters=True)
# graph = graphviz.Source(dot_data)
# graph.render("decision_tree")

# # Menampilkan visualisasi
# graph.view()

# %% [markdown]
# Code tersebut digunakan untuk memvisualisasikan model Decision Tree Classifier (DTC)
#
#
# [VISUALISASI DTC](https://drive.google.com/drive/folders/10EBB3qRggIyEI-ZwQS3e-x85sg_x7FjJ)

# %% [markdown]
# #**Evaluation**

# %% [markdown]
# ##**Evaluate Results**

# %% [markdown]
# ###**Klasifikasi (Predict Model)**

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,6))

class_names = ["Rendah", "Sedang", "Tinggi"]

gnb_cm = confusion_matrix(y_test, gnb_pred)
gnb_cm_display = ConfusionMatrixDisplay(gnb_cm, display_labels=class_names).plot(ax=axes[0], cmap='Blues')
gnb_cm_display.ax_.set_title("Gaussian Naive Bayes")
gnb_cm_display.ax_.invert_yaxis()  # Membalik sumbu y
gnb_cm_display.ax_.set_xticklabels(class_names)  # Label sumbu x
gnb_cm_display.ax_.set_yticklabels(class_names)  # Label sumbu y

knn_cm = confusion_matrix(y_test, knn_pred)
knn_cm_display = ConfusionMatrixDisplay(knn_cm, display_labels=class_names).plot(ax=axes[1], cmap='Greens')
knn_cm_display.ax_.set_title("K-Nearest Neighbor")
knn_cm_display.ax_.invert_yaxis()  # Membalik sumbu y
knn_cm_display.ax_.set_xticklabels(class_names)  # Label sumbu x
knn_cm_display.ax_.set_yticklabels(class_names)  # Label sumbu y

dtc_cm = confusion_matrix(y_test, dtc_pred)
dtc_cm_display = ConfusionMatrixDisplay(dtc_cm, display_labels=class_names).plot(ax=axes[2], cmap='Oranges')
dtc_cm_display.ax_.set_title("Decision Tree Classifier")
dtc_cm_display.ax_.invert_yaxis()  # Membalik sumbu y
dtc_cm_display.ax_.set_xticklabels(class_names)  # Label sumbu x
dtc_cm_display.ax_.set_yticklabels(class_names)  # Label sumbu y

plt.show()

# %% [markdown]
# Penjelasan dari Output diatas :
#
# Sebagai contoh untuk **METODE GNB**
# - Terdapat 226 Predicted label Rendah yang sesuai dengan label Rendah True (nyata) nya dan terdapat 91 dan 80 predicted label Rendah yang tidak sesuai dengan true label Rendah melainkan label Sedang dan Tinggi
#
# - Terdapat 25 Predicted label Sedang yang sesuai dengan label Sedang True (nyata) nya dan terdapat 36 dan 13 predicted label Sedang yang tidak sesuai dengan true label Sedang melainkan label Tinggi dan Rendah
#
# - Terdapat 828 Predicted label Tinggi yang sesuai dengan label Tinggi True (nyata) nya dan terdapat 136 dan 5 predicted label Tinggi yang tidak sesuai dengan true label Tinggi melainkan label Sedang dan Rendah.
#
# begitupula untuk metode KNN dan juga DTC mempunyai interpretasi yang sama dengan metode GNB hanya saja mesti lebih disesuaikan lagi angkanya dengan yang tertampilkan.

# %%
y_test
# Out:
#       user_rating
# 0               3
# 1               3
# 2               3
# 3               1
# 4               2
# ...           ...
# 1435            3
# 1436            1
# 1437            2
# 1438            1
# 1439            2
#
# [1440 rows x 1 columns]

# %%
# MANUAL
plt.figure(figsize=(20, 10))

class_names = [0,1,2]
matrix1 = gnb_cm
matrix2 = knn_cm
matrix3 = dtc_cm

TN_manual_Rendah = matrix1[1, 1] + matrix1[1, 2] + matrix1[2, 1] + matrix1[2, 2]
TN_manual_Sedang = matrix1[0, 0] + matrix1[0, 2] + matrix1[2, 0] + matrix1[2, 2]
TN_manual_Tinggi = matrix1[0, 0] + matrix1[0, 1] + matrix1[1, 0] + matrix1[1, 1]

plt.subplot(3, 3, 1)
sns.heatmap(pd.DataFrame([[matrix1[0, 0], matrix1[0, 1] + matrix1[0, 2]],
                          [matrix1[1, 0] + matrix1[2, 0], TN_manual_Rendah]],
                         index=['Rendah', 'Non-Rendah'], columns=['Rendah', 'Non-Rendah']), annot=True, fmt='g', cmap="Blues")
plt.title('GNB Confusion Matrix for Rendah')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.gca().invert_yaxis()

plt.subplot(3, 3, 2)
sns.heatmap(pd.DataFrame([[matrix1[1, 1], matrix1[1, 0] + matrix1[1, 2]],
                          [matrix1[0, 1] + matrix1[2, 1], TN_manual_Sedang]],
                         index=['Sedang', 'Non-Sedang'], columns=['Sedang', 'Non-Sedang']), annot=True, fmt='g', cmap="Blues")
plt.title('GNB Confusion Matrix for Sedang')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.gca().invert_yaxis()

plt.subplot(3, 3, 3)
sns.heatmap(pd.DataFrame([[matrix1[2, 2], matrix1[2, 0] + matrix1[2, 1]],
                          [matrix1[0, 2] + matrix1[1, 2], TN_manual_Tinggi]],
                         index=['Tinggi', 'Non-Tinggi'], columns=['Tinggi', 'Non-Tinggi']), annot=True, fmt='g', cmap="Blues")
plt.title('GNB Confusion Matrix for Tinggi')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.gca().invert_yaxis()


TN_manual_Rendah = matrix2[1, 1] + matrix2[1, 2] + matrix2[2, 1] + matrix2[2, 2]
TN_manual_Sedang = matrix2[0, 0] + matrix2[0, 2] + matrix2[2, 0] + matrix2[2, 2]
TN_manual_Tinggi = matrix2[0, 0] + matrix2[0, 1] + matrix2[1, 0] + matrix2[1, 1]


plt.subplot(3, 3, 4)
sns.heatmap(pd.DataFrame([[matrix2[0, 0], matrix2[0, 1] + matrix2[0, 2]],
                          [matrix2[1, 0] + matrix2[2, 0], TN_manual_Rendah]],
                         index=['Rendah', 'Non-Rendah'], columns=['Rendah', 'Non-Rendah']), annot=True, fmt='g', cmap="Greens")
plt.title('KNN Confusion Matrix for Rendah')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.gca().invert_yaxis()

plt.subplot(3, 3, 5)
sns.heatmap(pd.DataFrame([[matrix2[1, 1], matrix2[1, 0] + matrix2[1, 2]],
                          [matrix2[0, 1] + matrix2[2, 1], TN_manual_Sedang]],
                         index=['Sedang', 'Non-Sedang'], columns=['Sedang', 'Non-Sedang']), annot=True, fmt='g', cmap="Greens")
plt.title('KNN Confusion Matrix for Sedang')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.gca().invert_yaxis()

plt.subplot(3, 3, 6)
sns.heatmap(pd.DataFrame([[matrix2[2, 2], matrix2[2, 0] + matrix2[2, 1]],
                          [matrix2[0, 2] + matrix2[1, 2], TN_manual_Tinggi]],
                         index=['Tinggi', 'Non-Tinggi'], columns=['Tinggi', 'Non-Tinggi']), annot=True, fmt='g', cmap="Greens")
plt.title('KNN Confusion Matrix for Tinggi')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.gca().invert_yaxis()

TN_manual_Rendah = matrix3[1, 1] + matrix3[1, 2] + matrix3[2, 1] + matrix3[2, 2]
TN_manual_Sedang = matrix3[0, 0] + matrix3[0, 2] + matrix3[2, 0] + matrix3[2, 2]
TN_manual_Tinggi = matrix3[0, 0] + matrix3[0, 1] + matrix3[1, 0] + matrix3[1, 1]

plt.subplot(3, 3, 7)
sns.heatmap(pd.DataFrame([[matrix3[0, 0], matrix3[0, 1] + matrix3[0, 2]],
                          [matrix3[1, 0] + matrix3[2, 0], TN_manual_Rendah]],
                         index=['Rendah', 'Non-Rendah'], columns=['Rendah', 'Non-Rendah']), annot=True, fmt='g', cmap="Oranges")
plt.title('DTC Confusion Matrix for Rendah')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.gca().invert_yaxis()

plt.subplot(3, 3, 8)
sns.heatmap(pd.DataFrame([[matrix3[1, 1], matrix3[1, 0] + matrix3[1, 2]],
                          [matrix3[0, 1] + matrix3[2, 1], TN_manual_Sedang]],
                         index=['Sedang', 'Non-Sedang'], columns=['Sedang', 'Non-Sedang']), annot=True, fmt='g', cmap="Oranges")
plt.title('DTC Confusion Matrix for Sedang')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.gca().invert_yaxis()

plt.subplot(3, 3, 9)
sns.heatmap(pd.DataFrame([[matrix3[2, 2], matrix3[2, 0] + matrix3[2, 1]],
                          [matrix3[0, 2] + matrix3[1, 2], TN_manual_Tinggi]],
                         index=['Tinggi', 'Non-Tinggi'], columns=['Tinggi', 'Non-Tinggi']), annot=True, fmt='g', cmap="Oranges")
plt.title('DTC Confusion Matrix for Tinggi')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.gca().invert_yaxis()

plt.tight_layout()
plt.show()

# %%
# Otomatis

fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(17,10))

y_test_rendahOvR = [0 if y == 1 else 1 for y in y_test['user_rating']]
y_test_sedangOvR = [0 if y == 2 else 1 for y in y_test['user_rating']]
y_test_tinggiOvR = [0 if y == 3 else 1 for y in y_test['user_rating']]

gnb_pred_rendahOvR = [0 if y == 1 else 1 for y in gnb_pred]
gnb_pred_sedangOvR = [0 if y == 2 else 1 for y in gnb_pred]
gnb_pred_tinggiOvR = [0 if y == 3 else 1 for y in gnb_pred]

knn_pred_rendahOvR = [0 if y == 1 else 1 for y in knn_pred]
knn_pred_sedangOvR = [0 if y == 2 else 1 for y in knn_pred]
knn_pred_tinggiOvR = [0 if y == 3 else 1 for y in knn_pred]

dtc_pred_rendahOvR = [0 if y == 1 else 1 for y in dtc_pred]
dtc_pred_sedangOvR = [0 if y == 2 else 1 for y in dtc_pred]
dtc_pred_tinggiOvR = [0 if y == 3 else 1 for y in dtc_pred]

#----------------------------------------GNB OvR cONFUSION Matrix---------------------------------------------


gnb_cm_rendahOvR = confusion_matrix(y_test_rendahOvR, gnb_pred_rendahOvR)
gnb_cm_rendahOvR_display = ConfusionMatrixDisplay(gnb_cm_rendahOvR).plot(ax=axes[0,0], cmap='Blues')
gnb_cm_rendahOvR_display.ax_.set_title("Gaussian Naive Bayes Matrix rendah vs Non-rendah")
gnb_cm_rendahOvR_display.ax_.set_xlabel('Predicted Label')
gnb_cm_rendahOvR_display.ax_.set_ylabel('True Label')
gnb_cm_rendahOvR_display.ax_.set_xticklabels(['rendah', 'Non-rendah'])
gnb_cm_rendahOvR_display.ax_.set_yticklabels(['rendah', 'Non-rendah'])
gnb_cm_rendahOvR_display.ax_.invert_yaxis()

gnb_cm_sedangOvR = confusion_matrix(y_test_sedangOvR, gnb_pred_sedangOvR)
gnb_cm_sedangOvR_display = ConfusionMatrixDisplay(gnb_cm_sedangOvR).plot(ax=axes[0,1], cmap='Blues')
gnb_cm_sedangOvR_display.ax_.set_title("Gaussian Naive Bayes Matrix sedang vs Non-sedang")
gnb_cm_sedangOvR_display.ax_.set_xlabel('Predicted Label')
gnb_cm_sedangOvR_display.ax_.set_ylabel('True Label')
gnb_cm_sedangOvR_display.ax_.set_xticklabels(['sedang', 'Non-sedang'])
gnb_cm_sedangOvR_display.ax_.set_yticklabels(['sedang', 'Non-sedang'])
gnb_cm_sedangOvR_display.ax_.invert_yaxis()

gnb_cm_tinggiOvR = confusion_matrix(y_test_tinggiOvR, gnb_pred_tinggiOvR)
gnb_cm_tinggiOvR_display = ConfusionMatrixDisplay(gnb_cm_tinggiOvR).plot(ax=axes[0,2], cmap='Blues')
gnb_cm_tinggiOvR_display.ax_.set_title("Gaussian Naive Bayes Matrix tinggi vs Nom-tinggi")
gnb_cm_tinggiOvR_display.ax_.set_xlabel('Predicted Label')
gnb_cm_tinggiOvR_display.ax_.set_ylabel('True Label')
gnb_cm_tinggiOvR_display.ax_.set_xticklabels(['tinggi', 'Non-tinggi'])
gnb_cm_tinggiOvR_display.ax_.set_yticklabels(['tinggi', 'Non-tinggi'])
gnb_cm_tinggiOvR_display.ax_.invert_yaxis()

#----------------------------------------KNN OvR cONFUSION Matrix---------------------------------------------

knn_cm_rendahOvR = confusion_matrix(y_test_rendahOvR, knn_pred_rendahOvR)
knn_cm_rendahOvR_display = ConfusionMatrixDisplay(knn_cm_rendahOvR).plot(ax=axes[1,0], cmap='Greens')
knn_cm_rendahOvR_display.ax_.set_title("K-Nearest Neighbor Matrix rendah vs Non-rendah")
knn_cm_rendahOvR_display.ax_.set_xlabel('Predicted Label')
knn_cm_rendahOvR_display.ax_.set_ylabel('True Label')
knn_cm_rendahOvR_display.ax_.set_xticklabels(['rendah', 'Non-rendah'])
knn_cm_rendahOvR_display.ax_.set_yticklabels(['rendah', 'Non-rendah'])
knn_cm_rendahOvR_display.ax_.invert_yaxis()

knn_cm_sedangOvR = confusion_matrix(y_test_sedangOvR, knn_pred_sedangOvR)
knn_cm_sedangOvR_display = ConfusionMatrixDisplay(knn_cm_sedangOvR).plot(ax=axes[1,1], cmap='Greens')
knn_cm_sedangOvR_display.ax_.set_title("K-Nearest Neighbor Matrix sedang vs Non-sedang")
knn_cm_sedangOvR_display.ax_.set_xlabel('Predicted Label')
knn_cm_sedangOvR_display.ax_.set_ylabel('True Label')
knn_cm_sedangOvR_display.ax_.set_xticklabels(['sedang', 'Non-sedang'])
knn_cm_sedangOvR_display.ax_.set_yticklabels(['sedang', 'Non-sedang'])
knn_cm_sedangOvR_display.ax_.invert_yaxis()

knn_cm_tinggiOvR = confusion_matrix(y_test_tinggiOvR, knn_pred_tinggiOvR)
knn_cm_tinggiOvR_display = ConfusionMatrixDisplay(knn_cm_tinggiOvR).plot(ax=axes[1,2], cmap='Greens')
knn_cm_tinggiOvR_display.ax_.set_title("K-Nearest Neighbor Matrix tinggi vs Nom-tinggi")
knn_cm_tinggiOvR_display.ax_.set_xlabel('Predicted Label')
knn_cm_tinggiOvR_display.ax_.set_ylabel('True Label')
knn_cm_tinggiOvR_display.ax_.set_xticklabels(['tinggi', 'Non-tinggi'])
knn_cm_tinggiOvR_display.ax_.set_yticklabels(['tinggi', 'Non-tinggi'])
knn_cm_tinggiOvR_display.ax_.invert_yaxis()

#----------------------------------------DTC OvR cONFUSION Matrix---------------------------------------------

dtc_cm_rendahOvR = confusion_matrix(y_test_rendahOvR, dtc_pred_rendahOvR)
dtc_cm_rendahOvR_display = ConfusionMatrixDisplay(dtc_cm_rendahOvR).plot(ax=axes[2,0], cmap='Oranges')
dtc_cm_rendahOvR_display.ax_.set_title("Decision Tree Matrix rendah vs Non-rendah")
dtc_cm_rendahOvR_display.ax_.set_xlabel('Predicted Label')
dtc_cm_rendahOvR_display.ax_.set_ylabel('True Label')
dtc_cm_rendahOvR_display.ax_.set_xticklabels(['rendah', 'Non-rendah'])
dtc_cm_rendahOvR_display.ax_.set_yticklabels(['rendah', 'Non-rendah'])
dtc_cm_rendahOvR_display.ax_.invert_yaxis()

dtc_cm_sedangOvR = confusion_matrix(y_test_sedangOvR, dtc_pred_sedangOvR)
dtc_cm_sedangOvR_display = ConfusionMatrixDisplay(dtc_cm_sedangOvR).plot(ax=axes[2,1], cmap='Oranges')
dtc_cm_sedangOvR_display.ax_.set_title("Decision Tree Matrix sedang vs Non-sedang")
dtc_cm_sedangOvR_display.ax_.set_xlabel('Predicted Label')
dtc_cm_sedangOvR_display.ax_.set_ylabel('True Label')
dtc_cm_sedangOvR_display.ax_.set_xticklabels(['sedang', 'Non-sedang'])
dtc_cm_sedangOvR_display.ax_.set_yticklabels(['sedang', 'Non-sedang'])
dtc_cm_sedangOvR_display.ax_.invert_yaxis()

dtc_cm_tinggiOvR = confusion_matrix(y_test_tinggiOvR, dtc_pred_tinggiOvR)
dtc_cm_tinggiOvR_display = ConfusionMatrixDisplay(dtc_cm_tinggiOvR).plot(ax=axes[2,2], cmap='Oranges')
dtc_cm_tinggiOvR_display.ax_.set_title("Decision Tree Matrix tinggi vs Non-tinggi")
dtc_cm_tinggiOvR_display.ax_.set_xlabel('Predicted Label')
dtc_cm_tinggiOvR_display.ax_.set_ylabel('True Label')
dtc_cm_tinggiOvR_display.ax_.set_xticklabels(['tinggi', 'Non-tinggi'])
dtc_cm_tinggiOvR_display.ax_.set_yticklabels(['tinggi', 'Non-tinggi'])
dtc_cm_tinggiOvR_display.ax_.invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# Penjelasan Output diatas :
#
#
# Output diatas merupakan hasil pemetaan dari matrix confusion 3x3 dari setiap metode dalam klasifikasi. Pada pemetaan ini menggunakan metode OvR (One vs Rest), dan seperti namanya ini adalah salah satu metode untuk mengevaluasi model multiclass dengan membandingkan setiap label/kelas terhadap label/kelas lainnya pada waktu yang sama. Dalam skenario ini kita mengambil satu kelas dan menganggapnya sebagai kelas `positif` (0), sementara semua kelas lainnya (sisanya) dianggap sebagai kelas `negatif` (1) dengan melakukan ini, dapat mengurangi keluaran klasifikasi multiclass menjadi keluaran klasifikasi biner

# %%
from sklearn.metrics import roc_curve, auc

# Mendefinisikan subplots
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

# Menggambar kurva ROC untuk Gaussian Naive Bayes pada setiap subplot
for i, (y_true, y_pred, title) in enumerate(zip([y_test_rendahOvR, y_test_sedangOvR, y_test_tinggiOvR],
                                                 [gnb_pred_rendahOvR, gnb_pred_sedangOvR, gnb_pred_tinggiOvR],
                                                 ['rendah', 'sedang', 'tinggi'])):
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    ax = axes[i]
    ax.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    ax.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(f'ROC Curve - Gaussian Naive Bayes ({title})')
    ax.legend(loc='lower right')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Kode di atas berfungsi untuk memvisualisasikan kinerja kurva ROC untuk model Gaussian Naive Bayes dalam menangani masalah klasifikasi multiclass.
#
# Performa Klasifikasi:
#
# Ketiga kurva ROC menunjukkan performa klasifikasi yang baik dengan AUC (Area Under the Curve) yang tinggi:
#
# - Kurva ROC Gaussian Naive Bayes (rendah) memiliki AUC 0,89.
# - Kurva ROC Gaussian Naive Bayes (sedang) memiliki AUC 0,53.
# - Kurva ROC Gaussian Naive Bayes (tinggi) memiliki AUC 0,80.
#
# Perbandingan Performa:
#
# - Kurva ROC Gaussian Naive Bayes (rendah) memiliki AUC tertinggi, menunjukkan performa klasifikasi terbaik.
# - Kurva ROC Gaussian Naive Bayes (sedang) memiliki AUC terendah, menunjukkan performa klasifikasi terendah.
# - Kurva ROC Gaussian Naive Bayes (tinggi) memiliki performa klasifikasi di tengah-tengah.

# %%
# Menggambar kurva ROC untuk K-Nearest Neighbor pada setiap subplot
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

for i, (y_true, y_pred, title) in enumerate(zip([y_test_rendahOvR, y_test_sedangOvR, y_test_tinggiOvR],
                                                 [knn_pred_rendahOvR, knn_pred_sedangOvR, knn_pred_tinggiOvR],
                                                 ['rendah', 'sedang', 'tinggi'])):
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    ax = axes[i]
    ax.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    ax.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(f'ROC Curve - K-Nearest Neighbor ({title})')
    ax.legend(loc='lower right')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Kode di atas berfungsi untuk memvisualisasikan kinerja kurva ROC untuk model K-Nearest Neighbor dalam menangani masalah klasifikasi multiclass.
#
# Performa Klasifikasi:
#
# Ketiga kurva ROC menunjukkan performa klasifikasi yang berbeda:
#
# - Kurva ROC K-Nearest Neighbor (rendah) memiliki AUC 0,90, menunjukkan performa klasifikasi baik.
# - Kurva ROC K-Nearest Neighbor (sedang) memiliki AUC 0,70, menunjukkan performa klasifikasi buruk.
# - Kurva ROC K-Nearest Neighbor (tinggi) memiliki AUC 0,82, menunjukkan performa klasifikasi baik.
#
# Perbandingan Performa:
#
# - Kurva ROC K-Nearest Neighbor (rendah) dan (tinggi) memiliki AUC tinggi.
# - Kurva ROC K-Nearest Neighbor (sedang) memiliki AUC terendah, menunjukkan performa klasifikasi terburuk.

# %%
# Menggambar kurva ROC untuk Decision Tree Classifier pada setiap subplot
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))

for i, (y_true, y_pred, title) in enumerate(zip([y_test_rendahOvR, y_test_sedangOvR, y_test_tinggiOvR],
                                                 [dtc_pred_rendahOvR, dtc_pred_sedangOvR, dtc_pred_tinggiOvR],
                                                 ['rendah', 'sedang', 'tinggi'])):
    fpr, tpr, _ = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)
    ax = axes[i]
    ax.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    ax.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(f'ROC Curve - Decision Tree Classifier ({title})')
    ax.legend(loc='lower right')

# Menampilkan plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Kode di atas berfungsi untuk memvisualisasikan kinerja kurva ROC untuk model Decision Tree Classifier dalam menangani masalah klasifikasi multiclass. Terdapat kesimpulan untuk ketiga kurva tersebut yakni:
#
# Performa Klasifikasi:
#
# Ketiga kurva ROC menunjukkan performa klasifikasi yang berbeda:
#
# - Kurva ROC Decision Tree Classifier (rendah) memiliki AUC 0,93, menunjukkan performa klasifikasi sangat baik.
# - Kurva ROC Decision Tree Classifier (sedang) memiliki AUC 0,70, menunjukkan performa klasifikasi baik.
# - Kurva ROC Decision Tree Classifier (tinggi) memiliki AUC 0,81, menunjukkan performa klasifikasi baik.
#
# Perbandingan Performa:
#
# - Kurva ROC Decision Tree Classifier (rendah) memiliki AUC tertinggi, menunjukkan performa klasifikasi terbaik.
# - Kurva ROC Decision Tree Classifier (sedang) memiliki AUC terendah, menunjukkan performa klasifikasi terendah.
# - Kurva ROC Decision Tree Classifier (tinggi) memiliki performa klasifikasi di tengah-tengah.

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# Hitung nilai-nilai metrik untuk setiap model
accuracy_gnb = accuracy_score(y_test, gnb_pred)
accuracy_knn = accuracy_score(y_test, knn_pred)
accuracy_dtc = accuracy_score(y_test, dtc_pred)

precision_gnb = precision_score(y_test, gnb_pred, average='weighted')
precision_knn = precision_score(y_test, knn_pred, average='weighted')
precision_dtc = precision_score(y_test, dtc_pred, average='weighted')

recall_gnb = recall_score(y_test, gnb_pred, average='weighted')
recall_knn = recall_score(y_test, knn_pred, average='weighted')
recall_dtc = recall_score(y_test, dtc_pred, average='weighted')

f1_gnb = f1_score(y_test, gnb_pred, average='weighted')
f1_knn = f1_score(y_test, knn_pred, average='weighted')
f1_dtc = f1_score(y_test, dtc_pred, average='weighted')

# ROC-AUC scores tidak bisa dihitung langsung untuk multiclass classification

# Tampilkan nilai-nilai metrik untuk Gaussian Naive Bayes
print("Gaussian Naive Bayes")
print("Accuracy:", accuracy_gnb)
print("Precision:", precision_gnb)
print("Recall:", recall_gnb)
print("F1:", f1_gnb)
print("ROC rendah OvR: ",roc_auc_score(y_test_rendahOvR, gnb_pred_rendahOvR))
print("ROC sedang OvR: ",roc_auc_score(y_test_sedangOvR, gnb_pred_sedangOvR))
print("ROC tinggi OvR: ",roc_auc_score(y_test_tinggiOvR, gnb_pred_tinggiOvR))
print()

# Tampilkan nilai-nilai metrik untuk K-Nearest Neighbors
print("K-Nearest Neighbors")
print("Accuracy:", accuracy_knn)
print("Precision:", precision_knn)
print("Recall:", recall_knn)
print("F1:", f1_knn)
print("ROC rendah OvR: ",roc_auc_score(y_test_rendahOvR, knn_pred_rendahOvR))
print("ROC sedang OvR: ",roc_auc_score(y_test_sedangOvR, knn_pred_sedangOvR))
print("ROC tinggi OvR: ",roc_auc_score(y_test_tinggiOvR, knn_pred_tinggiOvR))
print()

# Tampilkan nilai-nilai metrik untuk Decision Tree Classifier
print("Decision Tree Classifier")
print("Accuracy:", accuracy_dtc)
print("Precision:", precision_dtc)
print("Recall:", recall_dtc)
print("F1:", f1_dtc)
print("ROC rendah OvR: ",roc_auc_score(y_test_rendahOvR, dtc_pred_rendahOvR))
print("ROC sedang OvR: ",roc_auc_score(y_test_sedangOvR, dtc_pred_sedangOvR))
print("ROC tinggi OvR: ",roc_auc_score(y_test_tinggiOvR, dtc_pred_tinggiOvR))
print()
# Out:
# Gaussian Naive Bayes
# Accuracy: 0.7493055555555556
# Precision: 0.7157462980952425
# Recall: 0.7493055555555556
# F1: 0.7138095614753409
# ROC rendah OvR:  0.8916264597839794
# ROC sedang OvR:  0.528980278980279
# ROC tinggi OvR:  0.7964222252597047
#
# K-Nearest Neighbors
# Accuracy: 0.8034722222222223
# Precision: 0.7993496144891122
# Recall: 0.8034722222222223
# F1: 0.7999861447776984
# ROC rendah OvR:  0.9010225341301605
# ROC sedang OvR:  0.6981120731120731
# ROC tinggi OvR:  0.8235887096774194
#
# Decision Tree Classifier
# Accuracy: 0.7951388888888888
# Precision: 0.8068368091785229
# Recall: 0.7951388888888888
# F1: 0.8001418456674146
# ROC rendah OvR:  0.9333433850540052
# ROC sedang OvR:  0.7017797017797018
# ROC tinggi OvR:  0.8126366867140513

# %% [markdown]
# berikut adalah nilai- nilai dari setiap metode yang digunakan dalam modelling predicted
#
# Dari kesimpulan di atas, kita dapat mengatakan bahwa model Decusindan Decision Tree Classifier menunjukkan kinerja yang lebih baik secara keseluruhan dibandingkan dengan K-Nearest Neighbors dan Gausian Naive Bayes dalam dataset ini.

# %% [markdown]
# ###**Klustering (Assosiate Model)**

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

silhouette_avg_kmeans = silhouette_score(x_final_norm, kmeans.labels_)
ch_score_kmeans = calinski_harabasz_score(x_final_norm, kmeans.labels_)
db_score_kmeans = davies_bouldin_score(x_final_norm, kmeans.labels_)

silhouette_avg_hc = silhouette_score(x_final_norm, hierarchy_clust)
ch_score_hc = calinski_harabasz_score(x_final_norm, hierarchy_clust)
db_score_hc = davies_bouldin_score(x_final_norm, hierarchy_clust)

metrics = ["Silhouette Score", "Calinski-Harabasz Score", "Davies-Bouldin Score"]
scores_kmeans = [silhouette_avg_kmeans, ch_score_kmeans, db_score_kmeans]
scores_hc = [silhouette_avg_hc, ch_score_hc, db_score_hc]

df_scores = pd.DataFrame({'': metrics,
                          'KMeans Score': scores_kmeans,
                          'Hierarchical Clustering (Agglomerative) Score': scores_hc})

df_scores = df_scores.set_index('')

df_scores = df_scores.T

display(df_scores)
# Out:
#                                                Silhouette Score  \
# KMeans Score                                           0.412132
# Hierarchical Clustering (Agglomerative) Score          0.408965
#
#                                                Calinski-Harabasz Score  \
# KMeans Score                                               4725.627986
# Hierarchical Clustering (Agglomerative) Score              4706.817366
#
#                                                Davies-Bouldin Score
# KMeans Score                                               0.940981
# Hierarchical Clustering (Agglomerative) Score              0.953210

# %% [markdown]
# **Kesimpulan**:
#
# 1. KMeans:
# - Memiliki skor Silhouette yang lebih tinggi 0.412132
# - Memiliki skor Calinski-Harabasz yang lebih tinggi 4725.627986
# - Memiliki skor Davies-Bouldin yang lebih rendah 0.940981
# 2. Hierarchical Clustering:
# - Memiliki skor Silhouette yang lebih rendah 0.408965
# - Memiliki skor Calinski-Harabasz yang lebih rendah 4706.817366
# - Memiliki skor Davies-Bouldin yang lebih tinggi 0.953210
#
# Berdasarkan skor, KMeans tampaknya memiliki performa yang sedikit lebih baik dalam hal pemisahan klaster, sedangkan Hierarchical Clustering memiliki performa yang sedikit lebih baik dalam hal variabilitas antar klaster.
#
# Note:
#
# - Silhouette : Mendekati 1, maka data yang digunakan sangat cocok dengan kluster yang terbagi. Kalau 0, maka data mendekati batas luar kedua kluster. Kalau mendekati -1 berarti data salah ditempatkan pada kluster yang seharusnya (penempatan kluster salah)
#
# - Calinski-Harabasz Score : Semakin tinggi, maka kluster terpisah semakin baik
#
# - Davies-Bouldin : Semakin kecil, maka semakin baik kluster terpisah

# %% [markdown]
# ##**REVIEW PROCESS**

# %% [markdown]
# #####**CROSS VALIDATION**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score

# Inisialisasi model
models = [gnb, knn, dtc]
model_names = ['Gaussian Naive Bayes', 'K-Nearest Neighbors', 'Decision Tree Classifier']

# Lakukan validasi silang untuk setiap model
cv_scores = []
for model in models:
    scores = cross_val_score(model, x_train_norm, y_train, cv=5)
    cv_scores.append(scores)

# Buat dataframe dari hasil validasi silang
df_cv_scores = pd.DataFrame(cv_scores, index=model_names).T

# Tampilkan visualisasi hasil validasi silang dengan lineplot
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_cv_scores, markers=True)
plt.title('Cross-Validation Scores for Different Models')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(title='Model', loc='lower right')
plt.xticks(ticks=range(5), labels=['Fold 1', 'Fold 2', 'Fold 3', 'Fold 4', 'Fold 5'])
plt.show()

# %% [markdown]
# #####**FEATURE SELECTION**

# %%
from sklearn.feature_selection import SelectKBest, chi2
import matplotlib.pyplot as plt

selector = SelectKBest(score_func=chi2, k='all')

selector.fit(x_train_norm, y_train)

feature_ranks = selector.scores_

feature_names = x_train.columns

feature_ranks_df = pd.DataFrame({'Feature': feature_names, 'Rank': feature_ranks})

feature_ranks_df = feature_ranks_df.sort_values(by='Rank', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature_ranks_df['Feature'], feature_ranks_df['Rank'], color='skyblue')
plt.xlabel('Rank')
plt.ylabel('Feature')
plt.title('Feature Ranking')
plt.gca().invert_yaxis()
plt.show()

# %%
feature_imp = pd.Series(dtc.feature_importances_, index=x.columns).sort_values(ascending=False)

sns.barplot(x=feature_imp, y=feature_imp.index)
plt.show()

# %% [markdown]
# #####**TUNING HYPERPARAMETER**

# %% [markdown]
# ###### Gaussian Naive Bayes

# %%
# TUNNING Gaussian Naive Bayes
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
param_grid = {
    'var_smoothing': np.logspace(0,-9, num=100)
}

grid_search = GridSearchCV(estimator=gnb, param_grid=param_grid, cv=5)

grid_search.fit(x_train_norm, y_train)

print("Parameter terbaik:", grid_search.best_params_)

y_pred_tuned = grid_search.best_estimator_.predict(x_test_norm)

acc_before_tuning = gnb.score(x_test_norm, y_test)
print("Akurasi sebelum tuning:", acc_before_tuning)

acc_after_tuning = grid_search.best_estimator_.score(x_test_norm, y_test)
print("Akurasi setelah tuning:", acc_after_tuning)
# Out:
# Parameter terbaik: {'var_smoothing': 0.001873817422860383}
# Akurasi sebelum tuning: 0.7493055555555556
# Akurasi setelah tuning: 0.7618055555555555

# %% [markdown]
# Dengan cara ini, kita melakukan penyetelan model Gaussian Naive Bayes untuk mencari nilai terbaik untuk parameter var_smoothing, yang kemudian dapat meningkatkan kinerja model. Namun dikarenakan skor tuningnya naik dibanding sebelumnya maka perlu menginisialisasikan GNB menggunakan hyperparameter tersebut

# %% [markdown]
# ###### K- Nearest Neighbor

# %%
# TUNNING K-Nearest Neighbor
# Definisikan grid parameter yang akan ditelusuri
param_grid = {
    'n_neighbors': range(1, 21),  # Coba nilai K dari 1 hingga 20
    'weights': ['uniform', 'distance'],  # Coba kedua jenis bobot
    'p': [1, 2]  # Coba kedua jenis jarak (Manhattan dan Euclidean)
}

# Lakukan pencarian grid dengan cross-validation
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, cv=5)

# Lakukan pelatihan pada data latih yang sudah dinormalisasi
grid_search.fit(x_train_norm, y_train)

# Cetak parameter terbaik yang ditemukan
print("Parameter terbaik:", grid_search.best_params_)

# Prediksi menggunakan model terbaik
y_pred_tuned = grid_search.best_estimator_.predict(x_test_norm)

# Hitung akurasi sebelum penyetelan (tuning)
acc_before_tuning = knn.score(x_test_norm, y_test)
print("Akurasi sebelum tuning:", acc_before_tuning)

# Hitung akurasi setelah penyetelan (tuning)
acc_after_tuning = grid_search.best_estimator_.score(x_test_norm, y_test)
print("Akurasi setelah tuning:", acc_after_tuning)
# Out:
# Parameter terbaik: {'n_neighbors': 16, 'p': 2, 'weights': 'uniform'}
# Akurasi sebelum tuning: 0.8034722222222223
# Akurasi setelah tuning: 0.7979166666666667

# %% [markdown]
# ###### Decision Tree Classifier

# %%
# Definisikan grid parameter yang akan ditelusuri
param_grid = {
    'criterion': ['gini', 'entropy'],  # Coba kedua jenis kriteria pemilihan fitur
    'max_depth': [None, 10, 20, 30, 40, 50],  # Coba beberapa kedalaman maksimum
    'min_samples_split': [2, 5, 10],  # Coba beberapa nilai minimum sampel untuk membagi node
    'min_samples_leaf': [1, 2, 4]  # Coba beberapa nilai minimum sampel di leaf node
}

# Lakukan pencarian grid dengan cross-validation
grid_search = GridSearchCV(estimator=dtc, param_grid=param_grid, cv=5)

# Lakukan pelatihan pada data latih yang sudah dinormalisasi
grid_search.fit(x_train_norm, y_train)

# Cetak parameter terbaik yang ditemukan
print("Parameter terbaik:", grid_search.best_params_)

# Prediksi menggunakan model terbaik
y_pred_tuned = grid_search.best_estimator_.predict(x_test_norm)

# Hitung akurasi sebelum penyetelan (tuning)
acc_before_tuning = dtc.score(x_test_norm, y_test)
print("Akurasi sebelum tuning:", acc_before_tuning)

# Hitung akurasi setelah penyetelan (tuning)
acc_after_tuning = grid_search.best_estimator_.score(x_test_norm, y_test)
print("Akurasi setelah tuning:", acc_after_tuning)
# Out:
# Parameter terbaik: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}
# Akurasi sebelum tuning: 0.8
# Akurasi setelah tuning: 0.8388888888888889

# %% [markdown]
# ###### K-Means

# %%
param_grid = {
    'n_clusters': [3, 4, 5, 6],  # Jumlah klaster yang akan dicoba
    'init': ['k-means++', 'random'],  # Metode inisialisasi centroid
    'algorithm': ['lloyd', 'elkan']  # Algoritma yang digunakan
}

# Evaluasi kualitas klastering menggunakan Silhouette Score
best_score = -1
best_params = None

for n_clusters in param_grid['n_clusters']:
    for init in param_grid['init']:
        for algorithm in param_grid['algorithm']:
            kmeans = KMeans(n_clusters=n_clusters, init=init, algorithm=algorithm, random_state=42, n_init='auto')
            labels = kmeans.fit_predict(x_final_norm)
            silhouette_avg = silhouette_score(x_final_norm, labels)
            print("Silhouette Score:", silhouette_avg, "dengan n_clusters =", n_clusters, ", init =", init, ", algorithm =", algorithm)
            if silhouette_avg > best_score:
                best_score = silhouette_avg
                best_params = {'n_clusters': n_clusters, 'init': init, 'algorithm': algorithm}

print("\nKombinasi terbaik:")
print(best_params)
print("Silhouette Score terbaik:", best_score)
# Out:
# Silhouette Score: 0.3741448801793287 dengan n_clusters = 3 , init = k-means++ , algorithm = lloyd
# Silhouette Score: 0.3741448801793287 dengan n_clusters = 3 , init = k-means++ , algorithm = elkan
# Silhouette Score: 0.41650803150422977 dengan n_clusters = 3 , init = random , algorithm = lloyd
# Silhouette Score: 0.41650803150422977 dengan n_clusters = 3 , init = random , algorithm = elkan
# Silhouette Score: 0.39578940364464477 dengan n_clusters = 4 , init = k-means++ , algorithm = lloyd
# Silhouette Score: 0.39578940364464477 dengan n_clusters = 4 , init = k-means++ , algorithm = elkan
# Silhouette Score: 0.43446347631853766 dengan n_clusters = 4 , init = random , algorithm = lloyd
# Silhouette Score: 0.43446347631853766 dengan n_clusters = 4 , init = random , algorithm = elkan
# Silhouette Score: 0.39879907320023306 dengan n_clusters = 5 , init = k-means++ , algorithm = lloyd
# Silhouette Score: 0.39879907320023306 dengan n_clusters = 5 , init = k-means++ , algorithm = elkan
# ...

# %% [markdown]
# ###### Hierarchical

# %%
param_grid = {
    'linkage': ['complete', 'average', 'single'],  # Metode penggabungan
    'metric': ['euclidean', 'manhattan', 'cosine']  # Metode pengukuran jarak
}

best_score = -1
best_params = None
# Evaluasi kualitas klastering menggunakan Silhouette Score

for metric in param_grid['metric']:
  for linkage in param_grid['linkage']:
    hierarchical_clustering = AgglomerativeClustering(n_clusters=3, metric= metric, linkage= linkage)
    labels = hierarchical_clustering.fit_predict(x_final_norm)
    silhouette_avg = silhouette_score(x_final_norm, labels)
    print("Silhouette Score:", silhouette_avg, "dengan kombinasi metric =",metric, ",linkage =",linkage)
    if silhouette_avg > best_score:
                best_score = silhouette_avg
                best_params = {'metric': metric, 'linkage': linkage}

hierarchical_clustering = AgglomerativeClustering(n_clusters=3, metric= 'euclidean', linkage= 'ward')
labels = hierarchical_clustering.fit_predict(x_final_norm)
silhouette_avg = silhouette_score(x_final_norm, labels)
print('-'*100)
print("\nDi bawah ini merupakan score dari model Hierical clustering yang digunakan sebelumnya pada Modelling Associate")
print("Silhouette Score:", silhouette_avg, "dengan kombinasi metric = eulicidan, linkage = ward")
print('-'*100)
print("\nKombinasi terbaik:")
print(best_params)
print("Silhouette Score terbaik:", best_score)
# Out:
# Silhouette Score: 0.40425192936893256 dengan kombinasi metric = euclidean ,linkage = complete
# Silhouette Score: 0.2335146433014967 dengan kombinasi metric = euclidean ,linkage = average
# Silhouette Score: 0.4175021188648406 dengan kombinasi metric = euclidean ,linkage = single
# Silhouette Score: 0.3468069853096694 dengan kombinasi metric = manhattan ,linkage = complete
# Silhouette Score: 0.21418781837269726 dengan kombinasi metric = manhattan ,linkage = average
# Silhouette Score: 0.2797769551385835 dengan kombinasi metric = manhattan ,linkage = single
# Silhouette Score: 0.4040454790250896 dengan kombinasi metric = cosine ,linkage = complete
# Silhouette Score: 0.24983602281289155 dengan kombinasi metric = cosine ,linkage = average
# Silhouette Score: 0.18235607806133872 dengan kombinasi metric = cosine ,linkage = single
# ----------------------------------------------------------------------------------------------------
#
# ...

# %% [markdown]
# Dikarenakan skor tuning dari ke-5 algoritma diatas naik dibandingkan sebelumnya maka akan dilakukan inisialisasi lagi menggunakan hyperparameter tersebut sesuai dengan algoritma masing-masing pada determine next steps.

# %% [markdown]
# ##**DETERMINE NEXT STEPS**

# %% [markdown]
# ###### Gaussian Naive Bayes

# %%
gnb = GaussianNB(var_smoothing=0.7680555555555556)
gnb.fit(x_train_norm, y_train)
# Out:
# GaussianNB(var_smoothing=0.7680555555555556)

# %% [markdown]
# ###### K-Nearest Neighbor

# %%
knn = KNeighborsClassifier(n_neighbors = 12, p = 2, weights = 'uniform')
knn.fit(x_train_norm, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=12)

# %% [markdown]
# ###### Decision Tree Classifier

# %%
dtc = DecisionTreeClassifier(criterion = 'entropy', max_depth = 10, min_samples_leaf = 1, min_samples_split = 10)
dtc.fit(x_train_norm, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_split=10)

# %%
gnb_pred = gnb.predict(x_test_norm)
knn_pred = knn.predict(x_test_norm)
dtc_pred = dtc.predict(x_test_norm)

# %%
x_test = pd.DataFrame(x_test).reset_index(drop=True)
y_test = pd.DataFrame(y_test).reset_index(drop=True)

gnb_col_new = pd.DataFrame(gnb_pred.astype(int), columns=["gnb_prediction_new"])
knn_col_new = pd.DataFrame(knn_pred.astype(int), columns=["knn_prediction_new"])
dtc_col_new = pd.DataFrame(dtc_pred.astype(int), columns=["dtc_prediction_new"])

combined_data = pd.concat([x_test, y_test, gnb_col, knn_col, dtc_col, gnb_col_new, knn_col_new, dtc_col_new], axis=1)

# %%
combined_data.head()
# Out:
#    rating_count_tot  rating_count_ver  user_rating_ver  prime_genre  \
# 0              1886                57              5.0            5
# 1              1452               207              4.0            1
# 2               104                54              4.0            5
# 3                 1                 1              1.0            1
# 4                 7                 0              0.0            5
#
#    sup_devices.num  lang.num  SizeCatg  PriceCatg  user_rating  \
# 0               37         1         0          1            3
# 1               38        14         0          0            3
# 2               43         3         2          1            3
# 3               38         8         0          0            1
# 4               40         1         2          1            2
#
#    gnb_prediction  knn_prediction  dtc_prediction  gnb_prediction_new  \
# 0               3               3               3                   3
# ...

# %% [markdown]
# ###### K-Means

# %%
kmeans = KMeans(n_clusters=6, random_state=42)
kmeans.fit(x_final_norm)
kmeans_clust = kmeans.predict(x_final_norm)


x_final = pd.DataFrame(x_final).reset_index(drop=True)

kmeans_col_new = pd.DataFrame(kmeans_clust, columns=["kmeans_cluster_new"])

combined_data_assoc = pd.concat([x_final, kmeans_col, kmeans_col_new], axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
combined_data_assoc.head()
# Out:
#    rating_count_tot  rating_count_ver  user_rating_ver  prime_genre  \
# 0             21292                26              4.5            5
# 1            161065                26              3.5            1
# 2            188583              2822              4.5            1
# 3            262241               649              4.5            1
# 4            985920              5320              5.0            1
#
#    sup_devices.num  lang.num  SizeCatg  PriceCatg  kmeans_cluster  \
# 0               38        10         1          1               0
# 1               37        23         1          0               2
# 2               37         3         1          0               2
# 3               37         9         1          0               2
# 4               37        45         0          0               2
#
#    kmeans_cluster_new
# 0                   2
# 1                   4
# 2                   4
# 3                   4
# 4                   0

# %% [markdown]
# ###### Hierarchical

# %%
hierarchy_clust = hc.fit_predict(x_final_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning:
#
# Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead

# %%
x_final = pd.DataFrame(x_final).reset_index(drop=True)

hierarchy_col_new = pd.DataFrame(hierarchy_clust, columns=["hierarchy_cluster_new"])

combined_data_assoc_newHC = pd.concat([x_final,kmeans_col, hierarchy_col_new], axis=1)

# %%
combined_data_assoc_newHC.sample(15)
# Out:
#       rating_count_tot  rating_count_ver  user_rating_ver  prime_genre  \
# 976                561                 4              5.0            1
# 3316               550                 2              3.5            1
# 281              15142                73              4.0            5
# 2685              3517              1187              4.0            5
# 6909                12                 6              4.0            1
# 724              13572                55              2.5            1
# 2721              2368                 1              5.0            2
# 4162                67                13              5.0            5
# 6407                 0                 0              0.0            5
# 552               5683                 7              4.5            2
# 6521                36                 0              0.0            5
# 4857               215               215              4.0            5
# ...

# %%
comparison_hc_after_tunning = pd.concat([x_final,hierarchy_col, hierarchy_col_new], axis=1)

# %%
comparison_hc_after_tunning.sample(10)
# Out:
#       rating_count_tot  rating_count_ver  user_rating_ver  prime_genre  \
# 5749              1735               125              4.5            1
# 3390               250                56              4.0            5
# 4847                11                 5              3.5            5
# 1559               850               448              4.5            5
# 519            2161558              1289              4.0            1
# 461                108                74              4.5            1
# 638                 53                 5              1.0            1
# 3475               917               158              5.0            5
# 5228                62                 7              4.5            2
# 2018            155903               713              4.5            5
#
#       sup_devices.num  lang.num  SizeCatg  PriceCatg  hierarchy_cluster  \
# 5749               37        31         0          0                  1
# ...

# %% [markdown]
# ## **Kesimpulan**

# %% [markdown]
# ---
#
# Dari evaluasi modelling di atas, dapat disimpulkan bahwa metode prediktif terbaik atau metode untuk melakukan klasifikasi ada pada metode Decision Tree C;Classifier sedangkan model terbaik untuk klustering atau asosiatif yakni pada hierarchical karena menunjukkan score yang lebih tinggi daripada metode K-Means.
#
#
# Setelah dilakukan tunnning hyperparameter didapatkan untuk metode metode seperti GNB, KNN, DTC, K-Means maupun Hierarchical perlu dimodelling ulang menggunakan hyperparameter yang lebih baik dari pada sebelumnya berdasarkan Silhouette score dari kombinasi hyperparameter
#
# ---

# %%
import pickle

pickle.dump(gnb, open('gnb.pkl', 'wb'))
pickle.dump(knn, open('knn.pkl','wb'))
pickle.dump(kmeans, open('kmeans.pkl','wb'))
pickle.dump(hierarchical_clustering, open('hierarchical.pkl','wb'))

# %%
df.to_csv('/content/Data Cleaned.csv', index=False)
