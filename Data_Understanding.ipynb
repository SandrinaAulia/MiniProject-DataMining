# %% [markdown]
# <a href="https://colab.research.google.com/github/SandrinaAulia/MiniProject-DataMining/blob/main/Data_Understanding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Analisis & Strategi Membangun Pengalaman Pengguna Sebagai Faktor Kunci Untuk Meningkatkan Unduhan Aplikasi pada Mobile App Store**

# %% [markdown]
# #**Import Library**

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# #**BUSINESS UNDERSTANDING**

# %% [markdown]
# ##**Business Objective**

# %% [markdown]
# Tujuan utama dari analisis ini adalah memberikan pedoman bagi pengembang aplikasi untuk memperhatikan strategi dan analisis yang relevan guna meningkatkan pertumbuhan dan retensi pengguna di masa depan, serta memastikan aplikasi mereka dapat ditemukan dengan mudah oleh lebih banyak orang. Selain itu, dengan menerapkan analisis yang tepat terhadap data Mobile App Store atau toko aplikasi seluler tersebut diharapkan hasil analisis ini dapat memberikan wawasan bagi pengembang aplikasi dan pemangku kepentingan lainnya dalam upaya meningkatkan kualitas aplikasi, mengidentifikasi tren, memperluas pangsa pasar dan merencanakan langkah-langkah yang diperlukan untuk mengoptimalkan pertumbuhan dan keberhasilan aplikasi mereka di toko aplikasi seluler (Mobile App Store).

# %% [markdown]
# ##**Assess Situation**

# %% [markdown]
# Dengan lingkungan yang terus berkembang dan pertumbuhan pesat jumlah aplikasi saat ini menambah tingkat persaingan yang tinggi di pasar. Para pengembang perlu memperhatikan berbagai faktor kunci untuk mengamankan kesuksesan aplikasi mereka di masa depan. Pemahaman yang mendalam tentang tren pasar, termasuk preferensi pengguna, aplikasi yang paling diminati, perkiraan harga yang sesuai, ukuran serta genre yang paling diinginkan oleh pengguna dan lain sebagainya juga harus diperhatikan. Selanjutnya, pengetahuan tentang pesaing di pasar sangat penting. Para pengembang perlu menganalisis aplikasi serupa yang sudah ada di pasar, mengevaluasi rating serta ulasan pengguna dan faktor eksternal lainnya yang mempengaruhi perkembangan teknologi.

# %% [markdown]
# ##**Data Mining Goals**

# %% [markdown]
# Tujuan dari analisis data ini adalah untuk mengidentifikasi faktor-faktor yang mempengaruhi perilaku unduhan dan penggunaan aplikasi seluler dalam toko aplikasi seluler (Mobile App Store), serta mengetahui faktor-faktor mana yang paling berpengaruh terhadap keberhasilan aplikasi tersebut menggunakan pemodelan prediktif. Analisis data mining juga bertujuan untuk mengidentifikasi pola dalam perilaku pengguna, seperti size atau ukuran, price atau harga, dan preferensi genre aplikasi. Selain itu, tujuan utamanya adalah memprediksi potensi kesuksesan suatu aplikasi dalam mencapai unduhan yang tinggi dan retensi pengguna yang baik di masa depan. Dengan memahami pola dan faktor-faktor yang mempengaruhi perilaku pengguna, pengembang aplikasi dapat menganalisis dan menyusun strategi pemasaran yang lebih efektif serta mengambil keputusan yang lebih baik dalam mengembangkan dan memasarkan aplikasi mereka di toko aplikasi seluler iOS (Mobile App Store).

# %% [markdown]
# ##**Project Plan**

# %% [markdown]
# Rencana proyek ini akan dimulai dengan pengumpulan data yang relevan terkait aplikasi seluler dari berbagai sumber yang tersedia, termasuk data dari Mobile App Store atau toko aplikasi seluler yang sudah ada sebelumnya. Setelah itu, dataset akan disaring dan dilakukan preprocessing data untuk memastikan kualitas dan konsistensi dataset yang akan digunakan dalam analisis. Langkah selanjutnya adalah melakukan eksplorasi data untuk memahami pola-pola yang ada dalam perilaku unduhan dan penggunaan aplikasi seluler (Mobile App), serta mengidentifikasi hubungan antar variabel yang relevan. Kemudian, dilakukan analisis data mining menggunakan pemodelan prediktif untuk mengidentifikasi faktor-faktor yang mempengaruhi keberhasilan aplikasi seluler, seperti ukuran aplikasi, harga, genre, ulasan dan lain sebagainya. Hasil dari analisis ini akan digunakan untuk menyusun strategi yang tepat guna meningkatkan pertumbuhan dan retensi pengguna di masa depan, serta memastikan aplikasi dapat ditemukan dengan mudah oleh lebih banyak orang. Dengan demikian, rencana proyek ini bertujuan untuk memberikan wawasan yang berharga bagi pengembang aplikasi dan pemangku kepentingan lainnya dalam upaya mengoptimalkan keberhasilan aplikasi mereka di toko aplikasi seluler (Mobile App Store).

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# ##**Collect Initial Data**

# %% [markdown]
# Sumber Data : [Dataset Mobile App (Apple iOS App Store)](https://www.kaggle.com/datasets/ramamet4/app-store-apple-data-set-10k-apps/data)
#
# Data diekstraksi dari iTunes Search API di situs web Apple Inc. yang berisi tentang komponen aplikasi, rating dari pengguna serta komponen lainnya yang berkaitan untuk memahami strategi yang akan mendorong pertumbuhan dan retensi pengguna di masa depan.

# %%
# Menampilkan dataraw/dataset
df = pd.read_csv("https://raw.githubusercontent.com/SandrinaAulia/MiniProject-DataMining/main/AppleStore.csv")
df
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# ...          ...         ...
# 7192       11081  1187617475
# 7193       11082  1187682390
# 7194       11087  1187779532
# 7195       11089  1187838770
# 7196       11097  1188375727
#
#                                              track_name  size_bytes currency  \
# 0                                       PAC-MAN Premium   100788224      USD
# 1                             Evernote - stay organized   158578688      USD
# 2       WeatherBug - Local Weather, Radar, Maps, Alerts   100524032      USD
# 3     eBay: Best App to Buy, Sell, Save! Online Shop...   128512000      USD
# 4                                                 Bible    92774400      USD
# ...                                                 ...         ...      ...
# ...

# %%
# Menampilkan 5 baris pertama
df.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
# Menampilkan 5 baris terakhir
df.tail()
# Out:
#       Unnamed: 0          id                                 track_name  \
# 7192       11081  1187617475                                      Kubik
# 7193       11082  1187682390                          VR Roller-Coaster
# 7194       11087  1187779532      Bret Michaels Emojis + Lyric Keyboard
# 7195       11089  1187838770  VR Roller Coaster World - Virtual Reality
# 7196       11097  1188375727               Escape the Sweet Shop Series
#
#       size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 7192   126644224      USD   0.00               142                75
# 7193   120760320      USD   0.00                30                30
# 7194   111322112      USD   1.99                15                 0
# 7195    97235968      USD   0.00                85                32
# 7196    90898432      USD   0.00                 3                 3
#
#       user_rating  user_rating_ver     ver cont_rating prime_genre  \
# ...

# %% [markdown]
# ##**Describe Data**

# %% [markdown]
# ####Informasi Dasar

# %%
# Menampilkan Jumlah Baris dan Kolom
df.shape
# Out:
# (7197, 17)

# %%
# Menampilkan Nama Kolom
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')

# %% [markdown]
# Pada data diatas yang telah ditampilkan memiliki jumlah baris dan kolom yakni sebanyak **7197 baris** dan **17 kolom**, dimana untuk kolom-kolom tersebut terdiri dari kolom Unnamed atau kolom tidak bernama, id, track name (nama aplikasi), size_bytes (ukuran aplikasi) dalam bytes dan lain sebagainya seperti yang sudah tertampilkan pada informasi dasar diatas.

# %% [markdown]
# ####Informasi Lanjutan

# %%
# Untuk menampilkan informasi dari dataraw/dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7197 non-null   int64
#  1   id                7197 non-null   int64
#  2   track_name        7197 non-null   object
#  3   size_bytes        7197 non-null   int64
#  4   currency          7197 non-null   object
#  5   price             7197 non-null   float64
#  6   rating_count_tot  7197 non-null   int64
#  7   rating_count_ver  7197 non-null   int64
#  8   user_rating       7197 non-null   float64
#  9   user_rating_ver   7197 non-null   float64
#  10  ver               7197 non-null   object
#  11  cont_rating       7197 non-null   object
#  12  prime_genre       7197 non-null   object
#  13  sup_devices.num   7197 non-null   int64
#  14  ipadSc_urls.num   7197 non-null   int64
#  15  lang.num          7197 non-null   int64
# ...

# %% [markdown]
# Pernyataan **"Non-Null Count : 7197"** menunjukkan bahwa dari total entri/data dalam kolom tersebut, ada 7197 data yang memiliki nilai non-null, atau dengan kata lain, tidak ada nilai null (atau missing value) dalam kolom tersebut.
#
# **Tipe Data :**
#
# * Integer64 (int64): Ini adalah tipe data untuk bilangan bulat.
#
# * Object: Tipe data object dalam Pandas biasanya digunakan untuk menyimpan teks atau kombinasi teks dan angka.
#
# * Float64 (float64): Tipe data float64 adalah representasi numerik untuk angka desimal.
#
#
# **Keterangan :**
#
# 1. **Unnamed** :yakni kolom tidak bernama memiliki tipe data int64 (integer)
# 2. **id** : yakni Id dari App dan memiliki tipe data int64 (integer)
# 3. **track_name** : yakni Nama App memiliki tipe data object
# 4. **size_bytes** : yakni Ukuran dari App dalam Bytes memiliki tipe data int64 (integer)
# 5. **currency** : yakni Jenis Mata Uang yang digunakan memiliki tipe data object
# 6. **price** : yakni Harga App memiliki tipe data float64
# 7. **rating_count_tot** : yakni Peringkat Pengguna dihitung (untuk semua versi)memiliki tipe data int64 (integer)
# 8. **rating_count_ver** : yakni Jumlah rating/Peringkat Pengguna (untuk versi saat ini) memiliki tipe data int64 (integer)
# 9. **user_rating** : yakni Nilai Rata-rata Peringkat Pengguna (untuk semua versi) memiliki tipe data float64
# 11. **user_rating_ver** : yakni Nilai Rata-rata Peringkat Pengguna (untuk versi saat ini) memiliki tipe data float64
# 12. **ver** : yakni Kode versi yang terbaru memiliki tipe data object
# 13. **cont_rating** : yakni Rating/Peringkat dari Konten memiliki tipe data object
# 14. **prime_genre** : yakni Genre Utama memiliki tipe data object
# 15. **sup_devices.num** : yakni Jumlah perangkat pendukung memiliki tipe data int64 (integer)
# 16. **ipadSc_urls.num** : yakni Jumlah screenshot yang ditampilkan untuk ditampilkan memiliki tipe data int64 (integer)
# 17. **lang.num** : yakni Jumlah bahasa yang didukung memiliki tipe data int64 (integer)
# 18. **vpp_lic** : yakni Perizinan Berbasis Perangkat Vpp Diaktifkan memiliki tipe data int64 (integer)

# %% [markdown]
# ####Informasi Statistik Deskriptif

# %%
# Menampilkan hasil statistik deskriptif untuk kolom numerik dalam data frame
df.describe()
# Out:
#          Unnamed: 0            id    size_bytes        price  \
# count   7197.000000  7.197000e+03  7.197000e+03  7197.000000
# mean    4759.069612  8.631310e+08  1.991345e+08     1.726218
# std     3093.625213  2.712368e+08  3.592069e+08     5.833006
# min        1.000000  2.816565e+08  5.898240e+05     0.000000
# 25%     2090.000000  6.000937e+08  4.692275e+07     0.000000
# 50%     4380.000000  9.781482e+08  9.715302e+07     0.000000
# 75%     7223.000000  1.082310e+09  1.819249e+08     1.990000
# max    11097.000000  1.188376e+09  4.025970e+09   299.990000
#
#        rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# count      7.197000e+03       7197.000000  7197.000000      7197.000000
# mean       1.289291e+04        460.373906     3.526956         3.253578
# std        7.573941e+04       3920.455183     1.517948         1.809363
# min        0.000000e+00          0.000000     0.000000         0.000000
# ...

# %% [markdown]
# Ini memberikan ringkasan statistik deskriptif untuk kolom numerik dalam DataFrame. Mencakup count(total data), mean, std (standar deviasi), min, quartil (25%, 50%, 75%), dan max untuk masing-masing kolom.
#
# Seperti contoh :
# **Kolom size_bytes** :
# 1. Rata-rata ukuran aplikasi dalam data adalah 1.99 bytes
# 2. Standar deviasi yakni 3.59 bytes
# 3. Rentang ukuran aplikasi sekitar 5.89 hingga 4.02 bytes
# 4. Q1 (kuartil ke-1 atau 25%) dari ukuran aplikasi yakni 4.69
# 5. Q2/median (kuartil ke-2 atau 50%) yakni skitar 9.71 bytes
# 6. Q3 (kuartil ke-3 atau 75%) adalah 1.81 bytes.
#
# Dari hal ini bisa dilihat bahwa mayoritas pengguna aplikasi menggunakan aplikasi berukuran 4.69 hingga 9.71 bytes.

# %%
# Menampilkan hasil statistik deskriptif baik itu numerik maupun non-numerik dalam data frame.
df.describe(include="all")
# Out:
#           Unnamed: 0            id         track_name    size_bytes currency  \
# count    7197.000000  7.197000e+03               7197  7.197000e+03     7197
# unique           NaN           NaN               7195           NaN        1
# top              NaN           NaN  VR Roller Coaster           NaN      USD
# freq             NaN           NaN                  2           NaN     7197
# mean     4759.069612  8.631310e+08                NaN  1.991345e+08      NaN
# std      3093.625213  2.712368e+08                NaN  3.592069e+08      NaN
# min         1.000000  2.816565e+08                NaN  5.898240e+05      NaN
# 25%      2090.000000  6.000937e+08                NaN  4.692275e+07      NaN
# 50%      4380.000000  9.781482e+08                NaN  9.715302e+07      NaN
# 75%      7223.000000  1.082310e+09                NaN  1.819249e+08      NaN
# max     11097.000000  1.188376e+09                NaN  4.025970e+09      NaN
#
# ...

# %% [markdown]
# Ini memberikan ringkasan statistik deskriptif untuk semua kolom dalam DataFrame, baik itu numerik maupun non-numerik. Untuk kolom numerik, informasinya sama seperti df.describe(). Namun, untuk kolom **non-numerik** (seperti objek), itu akan menyertakan jumlah unik, nilai yang paling sering muncul (top), dan frekuensi nilai teratas (freq).

# %%
# Menampilkan Korelasi
df.corr(numeric_only=True)
# Out:
#                   Unnamed: 0        id  size_bytes     price  \
# Unnamed: 0          1.000000  0.910714    0.041277 -0.074326
# id                  0.910714  1.000000    0.077486 -0.075247
# size_bytes          0.041277  0.077486    1.000000  0.182392
# price              -0.074326 -0.075247    0.182392  1.000000
# rating_count_tot   -0.168640 -0.201976    0.004486 -0.039044
# rating_count_ver   -0.064717 -0.072784    0.006337 -0.018012
# user_rating        -0.204867 -0.185178    0.066256  0.046601
# user_rating_ver    -0.127580 -0.109849    0.086075  0.025173
# sup_devices.num     0.024648  0.033605   -0.118347 -0.115361
# ipadSc_urls.num     0.014589  0.052082    0.152697  0.066100
# lang.num           -0.148487 -0.128932    0.004614 -0.006713
# vpp_lic             0.000501  0.017743   -0.150418 -0.029942
#
#                   rating_count_tot  rating_count_ver  user_rating  \
# Unnamed: 0               -0.168640         -0.064717    -0.204867
# ...

# %% [markdown]
# Korelasi :
#
# **1. Sizebytes**
# * Size_bytes dan user_rating_ver: Korelasi ini menunjukkan hubungan positif
# lemah (0,086075) antara ukuran file aplikasi (size_bytes) dan peringkat pengguna untuk versi aplikasi yang saat ini diulas. Ini menunjukkan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki peringkat pengguna versi terbaru yang sedikit lebih tinggi.
#
# * Size_bytes dan price: Korelasi ini menunjukkan hubungan positif lemah (0,182392) antara ukuran file aplikasi (size_bytes) dan harga aplikasi. Ini menunjukkan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki harga yang sedikit lebih tinggi.
#
# * Size_bytes dan user_rating: Korelasi ini menunjukkan hubungan positif lemah (0,066256) antara ukuran file aplikasi (size_bytes) dan peringkat pengguna keseluruhan. Ini menunjukkan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki peringkat pengguna yang sedikit lebih tinggi.
#
# * Size_bytes dan rating_count_ver: Korelasi ini menunjukkan bahwa tidak ada hubungan linier yang signifikan (0,006337) antara ukuran file aplikasi (size_bytes) dan jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas.
#
# * Size_bytes dan rating_count_tot: Korelasi ini menunjukkan bahwa tidak ada hubungan linier yang signifikan (0,004486) antara ukuran file aplikasi (size_bytes) dan jumlah total peringkat pengguna.
#
# * Size_bytes dan sup_devices.num: Korelasi ini menunjukkan hubungan negatif lemah (-0,118347) antara ukuran file aplikasi (size_bytes) dan jumlah perangkat yang mendukung aplikasi tersebut. Ini mungkin menunjukkan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki kompatibilitas yang sedikit lebih rendah dengan jumlah perangkat.
#
# * Size_bytes dan ipadSc_urls.num: Korelasi ini menunjukkan hubungan positif lemah (0,152697) antara ukuran file aplikasi (size_bytes) dan jumlah screenshot untuk perangkat iPad. Ini menandakan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki lebih banyak screenshot yang tersedia untuk perangkat iPad.
#
# * Size_bytes dan lang.num: Korelasi ini menunjukkan bahwa tidak ada hubungan linier yang signifikan (0,004614) antara ukuran file aplikasi (size_bytes) dan jumlah bahasa yang didukung oleh aplikasi.
#
# * Size_bytes dan vpp_lic: Korelasi ini menunjukkan hubungan negatif lemah (-0,150418) antara ukuran file aplikasi (size_bytes) dan status lisensi VPP (Volume Purchase Program). Ini mungkin menunjukkan bahwa aplikasi dengan ukuran file yang lebih besar cenderung memiliki peluang yang sedikit lebih rendah untuk memiliki lisensi VPP.
#
# **2. Price**
#
# * rating_count_tot dan price: Terdapat hubungan negatif lemah (-0.039044) antara jumlah total peringkat pengguna dan harga aplikasi. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna yang lebih tinggi cenderung memiliki harga yang sedikit lebih rendah, meskipun korelasinya sangat lemah.
#
# * rating_count_ver dan price: Terdapat hubungan negatif lemah (-0.018012) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan harga aplikasi. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna versi yang lebih tinggi cenderung memiliki harga yang sedikit lebih rendah, meskipun korelasinya sangat lemah.
#
# * user_rating dan price: Terdapat hubungan positif lemah (0.046601) antara peringkat pengguna keseluruhan dan harga aplikasi. Ini menunjukkan bahwa aplikasi dengan peringkat pengguna yang lebih tinggi cenderung memiliki harga yang sedikit lebih tinggi.
#
# * user_rating_ver dan price: Terdapat hubungan positif lemah (0.025173) antara peringkat pengguna untuk versi aplikasi yang saat ini diulas dan harga aplikasi. Ini menunjukkan bahwa aplikasi dengan peringkat pengguna versi yang lebih tinggi cenderung memiliki harga yang sedikit lebih tinggi.
#
# * sup_devices.num dan price: Terdapat hubungan negatif lemah (-0.115361) antara jumlah perangkat yang mendukung aplikasi dan harga aplikasi. Ini mungkin menunjukkan bahwa aplikasi dengan dukungan perangkat yang lebih luas cenderung memiliki harga yang sedikit lebih rendah.
#
# * ipadSc_urls.num dan price: Terdapat hubungan positif lemah (0.066100) antara jumlah screenshot untuk perangkat iPad dan harga aplikasi. Ini menandakan bahwa aplikasi dengan lebih banyak screenshot untuk perangkat iPad cenderung memiliki harga yang sedikit lebih tinggi.
#
# * lang.num dan price: Tidak terdapat hubungan linier yang signifikan (0.006713) antara jumlah bahasa yang didukung oleh aplikasi dan harga aplikasi.
#
# * vpp_lic dan price: Terdapat hubungan negatif lemah (-0.029942) antara status lisensi VPP (Volume Purchase Program) dan harga aplikasi. Ini mungkin menunjukkan bahwa aplikasi dengan lisensi VPP cenderung memiliki harga yang sedikit lebih rendah.
#
#
# **3. rating_count_ver**
# * rating_count_ver dan user_rating: Terdapat hubungan positif lemah (0.068754) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan peringkat pengguna keseluruhan. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna versi yang lebih tinggi cenderung memiliki peringkat pengguna keseluruhan yang juga lebih tinggi.
#
# * rating_count_ver dan user_rating_ver: Terdapat hubungan positif lemah (0.077840) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan peringkat pengguna untuk versi aplikasi tersebut. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna versi yang lebih tinggi cenderung memiliki peringkat pengguna versi tersebut yang juga lebih tinggi.
#
# * rating_count_ver dan sup_devices.num: Terdapat hubungan positif lemah (0.037951) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah perangkat yang mendukung aplikasi. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna versi yang lebih tinggi cenderung memiliki dukungan perangkat yang lebih luas.
#
# * rating_count_ver dan ipadSc_urls.num: Terdapat hubungan positif lemah (0.024333) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah screenshot untuk perangkat iPad. Ini menunjukkan bahwa aplikasi dengan jumlah peringkat pengguna versi yang lebih tinggi cenderung memiliki lebih banyak screenshot untuk perangkat iPad.
#
# * rating_count_ver dan lang.num: Tidak terdapat hubungan linier yang signifikan (0.013287) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah bahasa yang didukung oleh aplikasi.
#
# * rating_count_ver dan vpp_lic: Tidak terdapat hubungan linier yang signifikan (0.006460) antara jumlah peringkat pengguna untuk versi aplikasi yang saat ini diulas dan status lisensi VPP (Volume Purchase Program).
#
#
# **4. user_rating**
# * user_rating dan user_rating_ver: Terdapat hubungan positif yang sangat kuat (0.774140) antara peringkat pengguna keseluruhan dan peringkat pengguna untuk versi aplikasi yang saat ini diulas. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi secara keseluruhan juga cenderung mendapatkan peringkat tinggi untuk versi aplikasi yang saat ini diulas.
#
# * user_rating dan sup_devices.num: Terdapat hubungan negatif lemah (-0.042451) antara peringkat pengguna keseluruhan dan jumlah perangkat yang mendukung aplikasi. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi cenderung memiliki dukungan perangkat yang lebih rendah.
#
# * user_rating dan ipadSc_urls.num: Terdapat hubungan positif yang kuat (0.265671) antara peringkat pengguna keseluruhan dan jumlah screenshot untuk perangkat iPad. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi cenderung memiliki lebih banyak screenshot untuk perangkat iPad.
#
# * user_rating dan lang.num: Terdapat hubungan positif (0.170976) antara peringkat pengguna keseluruhan dan jumlah bahasa yang didukung oleh aplikasi. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi cenderung mendukung lebih banyak bahasa.
#
# * user_rating dan vpp_lic: Terdapat hubungan positif lemah (0.069816) antara peringkat pengguna keseluruhan dan status lisensi VPP (Volume Purchase Program). Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi cenderung memiliki kemungkinan sedikit lebih tinggi untuk memiliki lisensi VPP.
#
#
# **5. user_rating_ver**
#
# * user_rating_ver dan sup_devices.num: Terdapat hubungan negatif lemah (-0.018901) antara peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah perangkat yang mendukung aplikasi. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi untuk versi aplikasi yang saat ini diulas cenderung memiliki dukungan perangkat yang sedikit lebih rendah.
#
# * user_rating_ver dan ipadSc_urls.num: Terdapat hubungan positif yang kuat (0.275737) antara peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah screenshot untuk perangkat iPad. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi untuk versi aplikasi yang saat ini diulas cenderung memiliki lebih banyak screenshot untuk perangkat iPad.
#
# * user_rating_ver dan lang.num: Terdapat hubungan positif (0.175580) antara peringkat pengguna untuk versi aplikasi yang saat ini diulas dan jumlah bahasa yang didukung oleh aplikasi. Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi untuk versi aplikasi yang saat ini diulas cenderung mendukung lebih banyak bahasa.
#
# * user_rating_ver dan vpp_lic: Terdapat hubungan positif lemah (0.050094) antara peringkat pengguna untuk versi aplikasi yang saat ini diulas dan status lisensi VPP (Volume Purchase Program). Ini menunjukkan bahwa aplikasi yang mendapatkan peringkat tinggi untuk versi aplikasi yang saat ini diulas cenderung memiliki kemungkinan sedikit lebih tinggi untuk memiliki lisensi VPP.
#
# **6. sup_devices.num**
# * sup_devices.num dan ipadSc_urls.num: Terdapat hubungan negatif lemah (-0.037728) antara jumlah perangkat yang mendukung aplikasi dan jumlah screenshot untuk perangkat iPad. Ini menunjukkan bahwa aplikasi dengan dukungan perangkat yang lebih luas cenderung memiliki sedikit lebih sedikit screenshot untuk perangkat iPad.
#
# * sup_devices.num dan lang.num: Terdapat hubungan negatif lemah (-0.041681) antara jumlah perangkat yang mendukung aplikasi dan jumlah bahasa yang didukung oleh aplikasi. Ini menunjukkan bahwa aplikasi dengan dukungan perangkat yang lebih luas cenderung mendukung sedikit lebih sedikit bahasa.
#
# * sup_devices.num dan vpp_lic: Terdapat hubungan negatif lemah (-0.037109) antara jumlah perangkat yang mendukung aplikasi dan status lisensi VPP (Volume Purchase Program). Ini menunjukkan bahwa aplikasi dengan dukungan perangkat yang lebih luas cenderung memiliki peluang sedikit lebih rendah untuk memiliki lisensi VPP.
#
#
# **7. ipadSc_urls.num**
# * ipadSc_urls.num dan lang.num: Terdapat hubungan positif (0.088378) antara jumlah screenshot untuk perangkat iPad dan jumlah bahasa yang didukung oleh aplikasi. Ini menunjukkan bahwa aplikasi dengan lebih banyak screenshot untuk perangkat iPad cenderung juga mendukung lebih banyak bahasa.
#
# * ipadSc_urls.num dan vpp_lic: Terdapat hubungan positif (0.071901) antara jumlah screenshot untuk perangkat iPad dan status lisensi VPP (Volume Purchase Program). Ini menunjukkan bahwa aplikasi dengan lebih banyak screenshot untuk perangkat iPad cenderung memiliki peluang sedikit lebih tinggi untuk memiliki lisensi VPP.
#
# **8. lang.num**
#
# lang.num dan vpp_lic: Terdapat hubungan positif lemah (0.032477) antara jumlah bahasa yang didukung oleh aplikasi dan status lisensi VPP (Volume Purchase Program). Ini menunjukkan bahwa aplikasi yang mendukung lebih banyak bahasa cenderung memiliki peluang sedikit lebih tinggi untuk memiliki lisensi VPP.

# %% [markdown]
# ##**Exploratory Data Analysis**

# %%
# Konversi ukuran dari bytes ke Mega Bytes
df['size_mb'] = df['size_bytes'] / 1000000
summary_stats = df['size_mb'].describe() # Menampilkan statistik
print(summary_stats)
# Out:
# count    7197.000000
# mean      199.134454
# std       359.206914
# min         0.589824
# 25%        46.922752
# 50%        97.153024
# 75%       181.924864
# max      4025.969664
# Name: size_mb, dtype: float64

# %%
# Pembuatan kolom baru 'SizeCatg atau Size Category' dan inisialisasi dengan ukuran aplikasi dalam string
df['SizeCatg'] = df['size_mb'].astype(str)

# Proses pengklasifikasian aplikasi berdasarkan ukuran
for i in range(len(df['SizeCatg'])):
    if df.loc[i, 'size_mb'] < 100:
        df.loc[i, 'SizeCatg'] = 'Small Size App'
    elif df.loc[i, 'size_mb'] >= 100 and df.loc[i, 'size_mb'] < 300:
        df.loc[i, 'SizeCatg'] = 'Medium Size App'
    elif df.loc[i, 'size_mb'] >= 300 and df.loc[i, 'size_mb'] <= 5000:
        df.loc[i, 'SizeCatg'] = 'Big Size App'

# Mengubah klasifikasi ke format category
df['SizeCatg'] = pd.Categorical(df['SizeCatg'], categories=['Small Size App', 'Medium Size App', 'Big Size App'], ordered=True)

# Total masing-masing kategori ukuran aplikasi
summary_stats = df['SizeCatg'].value_counts()

print(summary_stats)
# Out:
# Small Size App     3702
# Medium Size App    2506
# Big Size App        989
# Name: SizeCatg, dtype: int64

# %%
# Jumlah Aplikasi berdasarkan Kategori Ukuran Aplikasi (size_bytes) dalam Plot Bar menggunakan Seaborn
sns.barplot(x=summary_stats.index, y=summary_stats.values, hue=summary_stats.index, palette="BuGn", legend=False)
plt.title('Jumlah Aplikasi iOS App Store Berdasarkan Kategori Ukuran')
plt.xlabel('Kategori Ukuran Aplikasi')
plt.ylabel('Jumlah')
plt.show()

# %% [markdown]
# Berdasarkan bar plot/grafik di atas, terlihat bahwa jumlah aplikasi dalam kategori ukuran kecil (Small Size App) > 3500, sedangkan jumlah aplikasi dalam kategori ukuran menengah (Medium Size App) sebanyak kurang lebih 2500, dan jumlah aplikasi dalam kategori ukuran besar (Big Size App) mendekati angka 1000. Meskipun perbedaan jumlahnya tidak signifikan, namun grafik menunjukkan bahwa aplikasi dalam kategori ukuran kecil memiliki jumlah yang paling banyak dibandingkan dengan kategori ukuran lainnya. Ini menunjukkan bahwa mayoritas aplikasi dalam dataset memiliki ukuran yang relatif kecil.

# %%
# Kategori Ukuran Aplikasi (size_bytes) berdasarkan Persentase menggunakan Pie Plot
sizes = df['SizeCatg'].value_counts()
colors = ['Honeydew', 'darkseagreen', 'seagreen']

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=sizes.index, autopct='%1.1f%%',startangle=160, colors=colors)
plt.title('Persentase Kategori Ukuran Aplikasi')
plt.axis('equal')  # Memastikan plot berbentuk lingkaran
plt.show()

# %% [markdown]
# Berdasarkan pie plot di atas, dapat disimpulkan bahwa jumlah aplikasi dalam kategori ukuran kecil (Small Size App) mendominasi dengan proporsi sebesar 51,4% dari total aplikasi. Diikuti oleh kategori ukuran menengah (Medium Size App) dengan proporsi sebesar 34,8%, dan kategori ukuran besar (Big Size App) dengan proporsi sebesar 13,7%. Hal ini menunjukkan bahwa mayoritas aplikasi dalam dataset memiliki ukuran yang relatif kecil, diikuti oleh aplikasi dengan ukuran menengah dan besar.

# %%
# Korelasi antara User Rating dan Kategori Ukuran Aplikasi dalam Box Plot menggunakan Plotly Express
fig = px.box(df, x='SizeCatg', y='user_rating_ver', color='SizeCatg',
             title='Persebaran Rating Berdasarkan Ukuran Aplikasi',
             labels={'SizeCatg': 'Kategori Ukuran Aplikasi', 'user_rating_ver': 'User Rating (Max = 5)'},
             template='plotly_white')

colors = ['mediumaquamarine', 'mediumseagreen',  'seagreen']
fig.update_traces(marker=dict(color=colors[0]), selector=dict(name='Small Size App'))
fig.update_traces(marker=dict(color=colors[1]), selector=dict(name='Medium Size App'))
fig.update_traces(marker=dict(color=colors[2]), selector=dict(name='Big Size App'))

# Menampilkan box plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Penjelasan Visualisasi diatas** :
# 1. Ukuran aplikasi yang besar menunjukan konsentrasi penilaian rating dari pengguna terpusat pada rentang penilaian 3.5 - 4.5 dengan rata-rata pengguna memberikan penilaian **rating 4.0** dari skala maksimal 5.
#
# 2. Ukuran aplikasi yang sedang menunjukan konsentrasi penilaian rating dari pengguna terpusat pada rentang penilaian 3.0 - 4.5 dengan rata-rata pengguna memberikan penilaian **rating 4.0** dari skala maksimal 5.
#
# 3. Ukuran aplikasi yang kecil menunjukan konsentrasi penilaian rating dari pengguna terpusat pada rentang penilaian 1.0 - 4.5 dengan rata-rata pengguna memberikan penilaian **rating 4.0** dari skala maksimal 5.
#
# **Insight :**
#
# 1. Bedasarkan visualisasi diatas kita mengetahui bahwa **semakin besar ukuran aplikasi** maka penilaian **rating** yang diberikan pengguna akan terkonsentrasi untuk memberikan **penilaian yang baik** (terkonsetrasi pada rentang 3.5 s.d 4.5)
#
# 2. Di sisi lain, **semakin kecil ukuran aplikasi**, maka penilaian **rating** yang diberikan pengguna akan semakin tersebar dimana rating yang diberikan akan **sangat beragam** (tersebar pada rentang 1.0 s.d 4.5)
#
# Dengan memperhatikan jenis kategori **ukuran aplikasi**, ditemukan bahwa hampir semua aplikasi dari ketiga kategori ukuran aplikasi tersebut memberikan **penilaian rating pengguna** sebesar **4.0/5.0.**
#
# Hal ini menunjukan bahwa mayoritas aplikasi yang terdaftar pada Mobile App Store tersebut dipandang baik oleh pengguna App Store, meskipun terdapat beberapa outlier, dimana memiliki nilai rating yang lebih rendah daripada mayoritas aplikasi lainnya serta menunjukkan adanya variasi dalam kualitas aplikasi yang tersedia, di mana beberapa aplikasi mungkin tidak memenuhi harapan atau preferensi pengguna.

# %%
# Pembuatan kolom baru 'PriceCatg'/ Price Category dan inisialisasi dengan harga aplikasi dalam string
df['PriceCatg'] = df['price'].astype(str)

# Proses pengklasifikasian aplikasi berdasarkan harga
for i in range(len(df['PriceCatg'])):
    if df.loc[i, 'price'] < 0.1:
        df.loc[i, 'PriceCatg'] = 'Gratis'
    elif df.loc[i, 'price'] >= 0.1 and df.loc[i, 'price'] < 10:
        df.loc[i, 'PriceCatg'] = 'Berbayar Murah'
    elif df.loc[i, 'price'] >= 10 and df.loc[i, 'price'] <= 50:
        df.loc[i, 'PriceCatg'] = 'Berbayar Sedang'
    elif df.loc[i, 'price'] > 50:
        df.loc[i, 'PriceCatg'] = 'Berbayar Mahal'

# Mengubah klasifikasi ke format category
df['PriceCatg'] = pd.Categorical(df['PriceCatg'], categories=['Gratis', 'Berbayar Murah', 'Berbayar Sedang', 'Berbayar Mahal'], ordered=True)

# Total masing-masing kategori harga aplikasi
summary_stats = df['PriceCatg'].value_counts()
print(summary_stats)
# Out:
# Gratis             4056
# Berbayar Murah     3044
# Berbayar Sedang      90
# Berbayar Mahal        7
# Name: PriceCatg, dtype: int64

# %%
# Menampilkan ringkasan statistik deskriptif dari kolom price
print("Ringkasan statistik deskriptif dari kolom price:")
print(df['price'].describe())
# Out:
# Ringkasan statistik deskriptif dari kolom price:
# count    7197.000000
# mean        1.726218
# std         5.833006
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.990000
# max       299.990000
# Name: price, dtype: float64

# %% [markdown]
# Dari dataset iOS App Store 2017, diketahui bahwa mayoritas aplikasi merupakan aplikasi gratis dengan jumlah 4.056 aplikasi terdaftar sedangkan harga aplikasi termahal adalah $299.9 USD.

# %%
# Korelasi antara Harga Aplikasi dan Kategori Ukuran Aplikasi dalam Box Plot menggunakan Plotly Express
fig = px.box(df, x='SizeCatg', y='price', color='SizeCatg',
             title='Persebaran Harga Berdasarkan Ukuran Aplikasi',
             labels={'SizeCatg': 'Kategori Ukuran Aplikasi', 'price': 'Harga Aplikasi (dalam satuan $USD)'},
             template='plotly_white')

colors = ['mediumaquamarine', 'mediumseagreen',  'seagreen']
fig.update_traces(marker=dict(color=colors[0]), selector=dict(name='Small Size App'))
fig.update_traces(marker=dict(color=colors[1]), selector=dict(name='Medium Size App'))
fig.update_traces(marker=dict(color=colors[2]), selector=dict(name='Big Size App'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1. Dari data diatas diketahui bahwa mayoritas aplikasi terdaftar adalah aplikasi gratis dengan jumlah 4.056 aplikasi terdaftar.
#
# 2. Di kategori aplikasi berbayar, terdapat 3.044 aplikasi berbayar murah (<10 USD), 90 aplikasi berbayar sedang (10 USD - 50 USD) dan 7 aplikasi berbayar mahal (>50 USD).

# %%
# Membuat box plot menggunakan Plotly Express
fig = px.box(df, x='PriceCatg', y='user_rating_ver', color='SizeCatg',
             title='Persebaran User Pada Versi App Store 2017',
             labels={'PriceCatg': 'Kategori Harga Aplikasi', 'user_rating_ver': 'User Rating (Max = 5)'},
             template='plotly_white')

colors = ['mediumaquamarine', 'olivedrab', 'seagreen']
fig.update_traces(marker=dict(color=colors[0]), selector=dict(name='Small Size App'))
fig.update_traces(marker=dict(color=colors[1]), selector=dict(name='Medium Size App'))
fig.update_traces(marker=dict(color=colors[2]), selector=dict(name='Big Size App'))
# Menampilkan box plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Dari hasil diatas kita dapat melihat bahwa aplikasi di :
# 1. kategori berbayar murah (<10 USD) dalam semua ukuran aplikasi (besar,sedang,kecil) memiliki penilaian rating terbaik dari pengguna, dimana rating penilaian terkonsentrasi pada rentang 3.0-4.5 dari skala 5.0.
#
# 2. Akan tetapi hal yang sama tidak dapat dikatakan untuk **kategori ukuran aplikasi** dan **kategori harga lainnya** dikarenakan baik untuk aplikasi yang **gratis** maupun **berbayar sedang dan mahal** memiliki respon feedback penilaian yang **cukup beragam dalam rentang penilaiannya.**

# %%
# Analisis Data Menggunakan Count Plot untuk Jumlah Aplikasi Berdasarkan Kategori Genre
color_palette = 'summer'

plt.figure(figsize=(10, 6))
ax = sns.countplot(y='prime_genre', data=df, palette=color_palette, hue='prime_genre', order=df['prime_genre'].value_counts().index)

for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width() + 0.1, p.get_y() + p.get_height() / 2), ha='left', va='center')

plt.title('Jumlah Aplikasi iOS App Store Berdasarkan Kategori', fontsize=16)
plt.xlabel('Jumlah', fontsize=12)
plt.ylabel('Genre Aplikasi', fontsize=12)

plt.show()

# %% [markdown]
# Berdasarkan hasil visualisasi Count Plot di atas menggambarkan sebaran jumlah aplikasi yang beredar pada ios Apps Store berdasarkan kategorinya. Semakin banyak suatu aplikasi muncul dalam suatu kategori semakin ke kanan arah yang ditunjukkan, sedangkan semakin sedikit akan semakin ke kiri arahnya. Ternyata aplikasi berkategori “GAMES” yang banyak beredar di ios Apps Store dengan jumlah aplikasi mencapai 3862, sedangkan aplikasi kecantikan “CATALOG” merupakan yang paling sedikit dengan jumlah 10 aplikasi.
#
# **Insight:**
#
# * Aplikasi kategori games memiliki jumlah 6x lipat dari kategori Entertainment di peingkat kedua dengan jumlah 500an aplikasi terdaftar.
#
# * Tiga aplikasi dengan jumlah terbanyak dan melebihi rata-rata di App Store adalah aplikasi dengan kategori genre “Games”, “Entertainment” dan “Education”.

# %%
# Korelasi Menggunakan Heatmap/Matriks Plot
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cbar=True, cmap="Greens")
plt.gcf().set_size_inches(15, 10)
plt.show()

# %% [markdown]
# Berdasarkan hasil visualisasi korelasi Heatmap di atas, terlihat bahwa setiap variabel memiliki nilai yang menggambarkan hubungannya dengan variabel lainnya. Sebagai contoh, variabel Size_bytes menunjukkan korelasi yang signifikan dengan user_rating_ver. Hal ini sesuai dengan analisis korelasi yang telah dilakukan sebelumnya. Dengan demikian, dapat disimpulkan bahwa ukuran aplikasi (Size_bytes) memiliki pengaruh yang cukup kuat terhadap nilai rata-rata peringkat pengguna untuk versi saat ini (user_rating_ver).

# %% [markdown]
# ####**KESIMPULAN**
#
# **- Ukuran Aplikasi**
#
# 1. Dari dataset iOS App Store 2017 terdapat 7.197 aplikasi seluler (mobile apps) yang terdaftar, dimana jumlah aplikasi dengan ukuran kecil (<100 Mb) memiliki jumlah terbesar dengan 3.702 aplikasi terdaftar sedangkan aplikasi dengan ukuran besar (>300 MB) memiliki jumlah terkecil dengan 989 aplikasi terdaftar.
#
# 2. Kita mengetahui bahwa semakin besar ukuran aplikasi maka penilaian rating yang diberikan pengguna akan terkonsentrasi untuk memberikan penilaian yang baik (terkonsetrasi pada rentang 3.5 s.d 4.5)
#
# 3. Dengan memperhatikan jenis kategori ukuran aplikasi, ditemukan bahwa hampir semua aplikasi dari ketiga kategori ukuran aplikasi memberikan penilaian rating pengguna sebesar 4.0/5.0. Hal ini menunjukan bahwa mayoritas aplikasi yang terdaftar dipandang baik oleh pengguna App Store, meskipun terdapat beberapa outlier dimana mendapatkan nilai yang lebih rendah daripada keseluruhan rentang penilaian grup.
#
#
# **- Harga Aplikasi**
# 1. Dari data diatas diketahui bahwa mayoritas aplikasi terdaftar adalah aplikasi gratis dengan jumlah 4.056 aplikasi terdaftar.
#
# 2. Di kategori aplikasi berbayar, terdapat 3.044 aplikasi berbayar murah (<10 USD), 90 aplikasi berbayar sedang (10 USD - 50 USD) dan 7 aplikasi berbayar mahal (>50 USD).
#
#
# **- Penilaian Rating**
#
# Penilaian rating dari pengguna secara konsisten mencatatkan rekam jejak yang baik untuk ukuran aplikasi besar (>300MB) untuk setiap kategori konten usia aplikasi dengan besaran rentang penilaian lebih besar dari 3.5 dalam skala 5.0.
#
#
#
# **- Kategori Genre Aplikasi**
#
# 1. Aplikasi kategori games memiliki jumlah 6x lipat dari kategori Entertainment di peingkat kedua dengan jumlah 500an aplikasi terdaftar.
#
# 2. Tiga aplikasi dengann jumlah terbanyak dan melebihi rata-rata di App Store adalah aplikasi dengan kategori genre “Games”, “Entertainment” dan “Education”.
#
# Untuk variabel yang saya visualisasikan kali ini cukup sampai disini saja meskipun masih terdapat beberapa variabel korelasi lainnya yang mungkin masih bisa dicoba untuk divisualisasikan, tetapi dari saya cukup memvisualisasikan sampai disini karena untuk variabel yang saya pilih merupakan yang paling umum biasanya dijadikan pertimbangan oleh pengguna maupun developer.

# %% [markdown]
# ##**Verify Data Quality**

# %% [markdown]
# ####Missing Values

# %%
# Mendeteksi nilai NaN/Null (Kosong) pada DataFrame Appstore (Cara 1)
nan_count = df.isna().sum()

# Menampilkan jumlah nilai NaN/Null (Kosong) untuk setiap kolom
print("Jumlah nilai NaN untuk setiap kolom:")
print(nan_count)
# Out:
# Jumlah nilai NaN untuk setiap kolom:
# Unnamed: 0          0
# id                  0
# track_name          0
# size_bytes          0
# currency            0
# price               0
# rating_count_tot    0
# rating_count_ver    0
# user_rating         0
# user_rating_ver     0
# ver                 0
# cont_rating         0
# prime_genre         0
# sup_devices.num     0
# ipadSc_urls.num     0
# lang.num            0
# vpp_lic             0
# size_mb             0
# SizeCatg            0
# PriceCatg           0
# dtype: int64

# %% [markdown]
# Dari output diatas, terlihat jika semua kolom memiliki nilai null/NaN yang sama yaitu 0. Jika Null/NaN adalah 0, itu berarti tidak ada data yang hilang atau kosong dalam kolom tersebut. Artinya, setiap baris dalam kolom memiliki nilai yang valid atau terisi.

# %%
#Mengecek apakah ada nilai null di dataset atau tidak (Cara 2)
df.isnull().any()
# Out:
# Unnamed: 0          False
# id                  False
# track_name          False
# size_bytes          False
# currency            False
# price               False
# rating_count_tot    False
# rating_count_ver    False
# user_rating         False
# user_rating_ver     False
# ver                 False
# cont_rating         False
# prime_genre         False
# sup_devices.num     False
# ipadSc_urls.num     False
# lang.num            False
# vpp_lic             False
# size_mb             False
# SizeCatg            False
# PriceCatg           False
# dtype: bool

# %% [markdown]
# **df.isnull().any()** digunakan untuk memeriksa apakah terdapat nilai null (kosong) dalam setiap kolom dari DataFrame `df`. any() digunakan untuk mengidentifikasi apakah setidaknya satu nilai null (True) terdapat dalam setiap kolom DataFrame.
#
# Jika terdapat nilai null dalam suatu kolom, maka nilai kembalian untuk kolom tersebut akan menjadi True, sedangkan jika tidak terdapat nilai null, maka nilai kembalian akan menjadi False. Dalam contoh di atas, output menunjukkan bahwa tidak ada nilai null dalam setiap kolom dari DataFrame `df`, karena semua nilai kembalian adalah False. Dengan demikian, dapat disimpulkan bahwa tidak ada nilai yang hilang (missing values) dalam dataset tersebut.

# %% [markdown]
# ####Outliers Values

# %%
outlier_results = []

for column in df.columns:
    if df[column].dtype in ['float64', 'int64']:  # Hanya mengambil kolom dengan tipe data numerik
        q1 = df[column].quantile(0.25)            # Menghitung nilai kuartil
        q3 = df[column].quantile(0.75)            # Menghitung nilai kuartil
        iqr = q3 - q1                             # Menghitung rentang interquartile (IQR)
        bts_bwh = q1 - 1.5 * iqr                  # Menghitung batas bawah dan batas atas untuk outlier
        bts_ats = q3 + 1.5 * iqr
        outliers = df[(df[column] < bts_bwh) | (df[column] > bts_ats)]    # Mencari outlier dalam kolom
        percent_outliers = (len(outliers) / len(df)) * 100                # Menghitung persentase outlier
        outlier_results.append({'Kolom': column, 'Persentase Outliers': percent_outliers})

# Membuat dataframe dari list hasil
outlier_df = pd.DataFrame(outlier_results)
outlier_df.set_index('Kolom', inplace=True)

display(outlier_df)
# Out:
#                   Persentase Outliers
# Kolom
# Unnamed: 0                   0.000000
# id                           0.000000
# size_bytes                  10.810060
# price                       11.560372
# rating_count_tot            17.104349
# rating_count_ver            14.742254
# user_rating                 14.297624
# user_rating_ver              0.000000
# sup_devices.num             27.441990
# ipadSc_urls.num              0.000000
# lang.num                     5.946922
# vpp_lic                      0.694734
# size_mb                     10.810060

# %% [markdown]
# Tabel di atas menggambarkan persentase outlier dalam setiap kolom dataset. Berikut adalah penjelasan untuk setiap kolom:
#
# 1. **Unnamed: 0**: Tidak ada outlier dalam kolom ini, menunjukkan bahwa tidak ada indeks data yang secara signifikan berbeda dari yang lain.
#
# 2. **id**: Tidak ada outlier dalam kolom ini, menunjukkan bahwa tidak ada ID aplikasi yang secara signifikan berbeda dari yang lain.
#
# 3. **size_bytes**: Terdapat outlier sebesar 10.81% dalam kolom ini, menunjukkan bahwa ada beberapa nilai ukuran aplikasi dalam bytes yang berbeda secara signifikan dari yang lain.
#
# 4. **price**: Terdapat outlier sebesar 11.56% dalam kolom ini, menunjukkan bahwa ada beberapa nilai harga aplikasi yang berbeda secara signifikan dari yang lain.
#
# 5. **rating_count_tot**: Terdapat outlier sebesar 17.10% dalam kolom ini, menunjukkan bahwa ada beberapa nilai jumlah total peringkat pengguna yang berbeda secara signifikan dari yang lain.
#
# 6. **rating_count_ver**: Terdapat outlier sebesar 14.74% dalam kolom ini, menunjukkan bahwa ada beberapa nilai jumlah peringkat pengguna untuk versi saat ini yang berbeda secara signifikan dari yang lain.
#
# 7. **user_rating**: Terdapat outlier sebesar 14.30% dalam kolom ini, menunjukkan bahwa ada beberapa nilai rata-rata peringkat pengguna untuk semua versi yang berbeda secara signifikan dari yang lain.
#
# 8. **user_rating_ver**: Tidak ada outlier dalam kolom ini, menunjukkan bahwa tidak ada data nilai rata-rata peringkat pengguna untuk versi saat ini yang berbeda secara signifikan dari yang lain.
#
# 9. **sup_devices.num**: Terdapat outlier sebesar 27.44% dalam kolom ini, menunjukkan bahwa ada beberapa nilai jumlah perangkat pendukung yang berbeda secara signifikan dari yang lain.
#
# 10. **ipadSc_urls.num**: Tidak ada outlier dalam kolom ini, menunjukkan bahwa tidak ada data jumlah URL screenshot yang berbeda secara signifikan dari yang lain.
#
# 11. **lang.num**: Terdapat outlier sebesar 5.95% dalam kolom ini, menunjukkan bahwa ada beberapa nilai jumlah bahasa yang didukung yang berbeda secara signifikan dari yang lain.
#
# 12. **vpp_lic**: Terdapat outlier sebesar 0.69% dalam kolom ini, menunjukkan bahwa ada beberapa nilai status lisensi berbasis perangkat VPP yang berbeda secara signifikan dari yang lain.
#
# 13. **size_mb**: Terdapat outlier sebesar 10.81% dalam kolom ini, menunjukkan bahwa ada beberapa nilai ukuran aplikasi dalam megabyte yang berbeda secara signifikan dari yang lain.

# %% [markdown]
# ####Duplicated Values

# %%
#Tambahkan kode untuk mengecek apakah ada nilai duplikat pada tiap kolom di dataset kalian ya
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7192    False
# 7193    False
# 7194    False
# 7195    False
# 7196    False
# Length: 7197, dtype: bool

# %% [markdown]
# Berdasarkan hasil dari analisis awal serta output diatas, dapat disimpulkan bahwa data tersebut menunjukkan kualitas yang baik karena tidak mengandung nilai yang kosong atau duplikat. Sehingga, dataset ini tidak memerlukan tindakan lebih lanjut terkait dengan duplikasi data.

# %% [markdown]
# ####Inconsistent Values / Noise (Optional)

# %%
[print(f"Columns -> {col}\n{df[col].unique()}\n{'-' * 30}\n") for col in df.columns]
# Out:
# Columns -> Unnamed: 0
# [    1     2     3 ... 11087 11089 11097]
# ------------------------------
#
# Columns -> id
# [ 281656475  281796108  281940292 ... 1187779532 1187838770 1188375727]
# ------------------------------
#
# Columns -> track_name
# ['PAC-MAN Premium' 'Evernote - stay organized'
#  'WeatherBug - Local Weather, Radar, Maps, Alerts' ...
#  'Bret Michaels Emojis + Lyric Keyboard'
#  'VR Roller Coaster World - Virtual Reality'
#  'Escape the Sweet Shop Series']
# ------------------------------
#
# Columns -> size_bytes
# [100788224 158578688 100524032 ... 111322112  97235968  90898432]
# ------------------------------
#
# Columns -> currency
# ['USD']
# ------------------------------
#
# Columns -> price
# [  3.99   0.     0.99   9.99   4.99   7.99   2.99   1.99   5.99  12.99
#   21.99 249.99   6.99  74.99  19.99   8.99  24.99  13.99  14.99  16.99
#   47.99  11.99  59.99  15.99  27.99  17.99 299.99  49.99  23.99  20.99
#   39.99  99.99  29.99  34.99  18.99  22.99]
# ...

# %% [markdown]
# Tidak terlihat adanya nilai yang inkonsisten atau noise yang dapat diamati secara langsung dari output tersebut. Semua kolom memiliki nilai yang sesuai dengan jenis data yang diharapkan, tanpa adanya anomali yang mencolok.
